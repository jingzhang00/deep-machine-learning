# %% [markdown]
# ### Checklist for submission
#
# It is extremely important to make sure that:
#
# 1. Everything runs as expected (no bugs when running cells);
# 2. The output from each cell corresponds to its code (don't change any cell's contents without rerunning it afterwards);
# 3. All outputs are present (don't delete any of the outputs);
# 4. Fill in all the places that say `# YOUR CODE HERE`, or "**Your answer:** (fill in here)".
# 5. Never copy/paste any notebook cells. Inserting new cells is allowed, but it should not be necessary.
# 6. The notebook contains some hidden metadata which is important during our grading process. **Make sure not to corrupt any of this metadata!** The metadata may for example be corrupted if you copy/paste any notebook cells, or if you perform an unsuccessful git merge / git pull. It may also be pruned completely if using Google Colab, so watch out for this. Searching for "nbgrader" when opening the notebook in a text editor should take you to the important metadata entries.
# 7. Although we will try our very best to avoid this, it may happen that bugs are found after an assignment is released, and that we will push an updated version of the assignment to GitHub. If this happens, it is important that you update to the new version, while making sure the notebook metadata is properly updated as well. The safest way to make sure nothing gets messed up is to start from scratch on a clean updated version of the notebook, copy/pasting your code from the cells of the previous version into the cells of the new version.
# 8. If you need to have multiple parallel versions of this notebook, make sure not to move them to another directory.
# 9. Although not forced to work exclusively in the course `conda` environment, you need to make sure that the notebook will run in that environment, i.e. that you have not added any additional dependencies.
#
# **FOR HA1, HA2, HA3 ONLY:** Failing to meet any of these requirements might lead to either a subtraction of POEs (at best) or a request for resubmission (at worst).
#
# We advise you to perform the following steps before submission to ensure that requirements 1, 2, and 3 are always met: **Restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All). This might require a bit of time, so plan ahead for this (and possibly use a cloud GPU in HA1 and HA2 for this step). Finally press the "Save and Checkout" button before handing in, to make sure that all your changes are saved to this .ipynb file.

# %% [markdown]
# ### Fill in name of notebook file
# This might seem silly, but the version check below needs to know the filename of the current notebook, which is not trivial to find out programmatically.
#
# You might want to have several parallel versions of the notebook, and it is fine to rename the notebook as long as it stays in the same directory. **However**, if you do rename it, you also need to update its own filename below:

# %%
nb_fname = "HA1.ipynb"

# %% [markdown]
# ### Fill in group number and member names (use NAME2 and GROUP only for HA1, HA2 and HA3):

# %%
NAME1 = "Peilin Lyu" 
NAME2 = "Jing Zhang"
GROUP = "Group 6"

# %% [markdown]
# ### Check Python version

# %%
from platform import python_version_tuple
assert python_version_tuple()[:2] == ('3','9'), "You are not running Python 3.9. Make sure to run Python through the course Conda environment."

# %% [markdown]
# ### Check that notebook server has access to all required resources, and that notebook has not moved

# %%
import os
nb_dirname = os.path.abspath('')
assignment_name = os.path.basename(nb_dirname)
assert assignment_name in ['IHA1', 'IHA2', 'HA1', 'HA2', 'HA3'], \
    '[ERROR] The notebook appears to have been moved from its original directory'

# %%
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ### Verify correct nb_fname

# %%
from IPython.display import display, HTML
try:
    display(HTML(r'<script>if("{nb_fname}" != IPython.notebook.notebook_name) {{ alert("You have filled in nb_fname = \"{nb_fname}\", but this does not seem to match the notebook filename \"" + IPython.notebook.notebook_name + "\"."); }}</script>'.format(nb_fname=nb_fname)))
except NameError:
    assert False, 'Make sure to fill in the nb_fname variable above!'
# Out:
# <script>if("HA1.ipynb" != IPython.notebook.notebook_name) { alert("You have filled in nb_fname = \"HA1.ipynb\", but this does not seem to match the notebook filename \"" + IPython.notebook.notebook_name + "\"."); }</script>

# %% [markdown]
# ### Verify that your notebook is up-to-date and not corrupted in any way

# %%
import sys
sys.path.append('..')
from ha_utils import check_notebook_uptodate_and_not_corrupted
check_notebook_uptodate_and_not_corrupted(nb_dirname, nb_fname)
# Out:
# Matching current notebook against the following URL:
# http://raw.githubusercontent.com/dml-cth/deep-machine-learning/master/home-assignments/HA1/HA1.ipynb
# [SUCCESS] No major notebook mismatch found when comparing to latest GitHub version. (There might be minor updates, but even that is the case, submitting your work based on this notebook version would be acceptable.)

# %% [markdown]
# # HA1 - Cats and dogs

# %% [markdown]
# <img src="https://cdn.pixabay.com/photo/2015/05/20/10/03/cat-and-dog-775116_960_720.jpg" alt="Image of cats and dogs" style="width: 500px;"/>

# %% [markdown]
# For this home assignment, we'll use the Kaggle dataset for the [Dogs vs. Cats competition](https://www.kaggle.com/c/dogs-vs-cats). It is comprised of 25k colour images of dogs and cats. Our goal with this assignment will be to create a classifier that can discriminate between cats or dogs.
#
# The goal is to make sure that you all can independently create, train and evaluate a model using a popular deep learning framework. A secondary goal is also to expose you to GPU computing, either your own or via a cloud computing service. The focus is on implementing the models, and much of the surrounding code is provided for you. You are expected to understand the provided code.

# %% [markdown]
# ## Using your cloud GPU
#
# ### Strong recommendation:
# In order to make the most out of your GPU hours, first try solving the initial part of this notebook (tasks 0-3) in your own computer (these tasks can be solved on the CPU), and leave most of the available hours for solving tasks 4-5, and refining your best model further (and, if you have the spare hours, experiment a bit! (Task 6)).
#
# There may well be difficult to access a cloud GPU, we therefore suggest that you start working with the cloud parts as soon as possible. You do not need to complete tasks 2-3 before you start with the GPU requiring tasks (tasks 4-6). A suggested workflow is to complete the task 0-1, start with task 2 and then work on task 2-3 and 4-6 in parallell.
#
# ### Working efficiently:
# Training for several epochs just to have your code break at the last validation step is incredibly frustrating and inefficient. Good practice is to first test long training runs with a much simpler dry-run: a single epoch, a few batches et c.

# %% [markdown]
# Requirements:
# - Whenever we ask you to plot anything, be sure to add a title and label the axes. If you're plotting more than one curve in the same plot, also add a legend.
# - When we ask you to train an architecture, train it for a reasonable number of epochs. "Reasonable" here means you should be fairly confident that training for a higher number of epochs wouldn't impact your conclusions regarding the model's performance. When experimenting, a single epoch is often enough to tell whether your model setup has improved or not.
#
#
# Hints:
# - If you get errors saying you've exhausted the GPU resources, well, then you've exhausted the GPU resources. However, sometimes that's because Pytorch didn't release a part of the GPU's memory. If you think your CNN should fit in your memory during training, try restarting the kernel and directly training only that architecture.
# - Every group has enough cloud credits to complete this assignment. However, this statement assumes you'll use your resources judiciously (e.g. always try the code first in your machine and make sure everything works properly before starting your instances) and **won't forget to stop your instance after using it,**  otherwise you might run out of credits.
# - Before starting, take a look at the images we'll be using. This is a hard task, don't get discouraged if your first models perform poorly (several participants in the original competition didn't achieve an accuracy higher than 60%).
# - Solving the computer labs and individual home assignments is a good way to get prepared for this assignment.

# %% [markdown]
# ---
# ## 0. Imports
#
# In the following cell, add all the imports you'll use in this assignment.

# %%
# YOUR CODE HERE
from pathlib import Path
import matplotlib.pyplot as plt
import torch
from torchvision.transforms import Resize
from torchvision import transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
import seaborn as sns
import numpy as np
from torch.utils.data import Dataset
from torchvision.transforms import Compose, ToTensor

# %% [markdown]
# ---
# ## 1. Loading the data and preprocessing
#
# In this part we will set up the data used in this assignment. You need to download it, then we'll walk you through how to make a custom Pytorch dataset abstraction. The abstraction enables you to visualise and play around with the image data and to finally create data loaders, which are necessary for the training.

# %% [markdown]
# The first step is to head to the [Kaggle website for the cats and dogs competition](https://www.kaggle.com/c/dogs-vs-cats/data) and download the data from there. You should download both the test and train folders together in one zip file (there is a `Download all` button at the bottom of the page). Unfortunately, you need to create a Kaggle account for this.
#
# **Only necessary for tasks 4-6**: Downloading the data to your local computer is quite straight-forward. Sooner or later you will have to upload the data to the cloud instance and that is a bit more tricky. There are a few ways to do it:
#
#  - Jupyter Notebook upload function. When starting the notebook server with the command `jupyter notebook` you are directed to a main page. In the top right corner there is an upload button.
#  - Using [`scp`](https://linuxize.com/post/how-to-use-scp-command-to-securely-transfer-files/) to copy files via an ssh connection.
#  - Using the [Kaggle CLI](https://github.com/Kaggle/kaggle-api). We have added it to the conda environment.
#
# To begin with, download the data to your local computer and create a folder structure that resembles the following (obviously, the folder names are up to you):
#
#
#          small_train             small_val                train                   val
#               |                      |                      |                      |
#               |                      |                      |                      |
#         -------------          -------------          -------------          -------------
#         |           |          |           |          |           |          |           |
#         |           |          |           |          |           |          |           |
#       cats        dogs       cats        dogs       cats        dogs       cats        dogs
#
#
# The `small_train` and `small_val` folders have the training and validation samples for your smaller subset of the data, while the `train` and `val` folders contain all the samples you extracted from Kaggle's `train.zip`.
# This is just a convenient way of having a smaller dataset to play with for faster prototyping.
#
# We provide you a notebook that shows how to achieve this folder structure (`create_project_notebook_structure.ipynb`), starting from the original `dogs-vs-cats.zip` file that you download from Kaggle. If you do use that notebook, we encourage you to understand how each step is being done, so you can generalize this knowledge to new datasets you'll encounter.

# %% [markdown]
# **(2 points)**
#
# For the smaller dataset, we advise you to use 70% of the data as training data (and thereby the remaining 30% for validation data). However, for the larger dataset, you should decide how to split between training and validation.
#
# **What percentage of the larger dataset did you decide to use for training?**
#
# **Did you decide to keep the same ratio split between train and validation sets for the larger dataset? Motivate your decision!**

# %% [markdown]
# **Your answer:**
#
# We decide to use 80% as training data, 20% as validation.
# 1. With a larger dataset, our model can learn more patterns and complexities in the data.
# 2. The representation power of a smaller percentage for validation improves as the dataset size increases.

# %% [markdown]
# Fill in the dataset paths (to be used later by your data loaders):

# %%
# TODO: Change the directories accordingly
train_path = "train"
val_path = "val"
small_train_path = "small_train"
small_val_path = "small_val"
# YOUR CODE HERE

# %% [markdown]
# ### 1.1 Dataset
#
# To create data loaders we first need to create a dataset abstraction class. The purpose of a data loader is to efficiently provide the CPU/GPU with mini-batches of data. We now work with data complex enough to actually warrant the use of data loaders. In particular, we don't want to load all images into memory at once.
#
# Like before, the data loader is an instance of the Pytorch [`DataLoader`](https://pytorch.org/docs/stable/data.html?highlight=dataloader#torch.utils.data.DataLoader) which wraps a class that inherits from [`Dataset`](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset), that we create ourselves.
# Image classification is such a common task that Pytorch provides a ready-to-use dataset class for this task, called [`ImageFolder`](https://pytorch.org/vision/stable/datasets.html?highlight=imagefolder#imagefolder).
# Using this class however, is rather opaque so for your understanding we will show you how to construct a custom dataset class. If you know this method, you will be able to create a data loader for any dataset you may encounter.
#
# We construct a class `DogsCatsData` as a subclass of `Dataset`.
# The dataset subclass holds the actual data, or at least provides access to it.
# To make it work with the `DataLoader` class we need to implement two methods:
#
# - `__getitem__(self, index)`: return the `index`'th sample, i.e. a single pair of (image, label)
# - `__len__(self)`: simply return the total number of samples $N$ in the dataset.
#
# These methods are so called Python "magic" methods, signified by the leading and closing double underscores.
# They typically enable special syntax for a class: `__getitem__` enables indexing of a class, and `__len__` enables calling the `len` function:
# ```python
# # Consider an instance `data` of a class `MyDataset` implementing `__getitem__` and `__len__`
# data[10] # returns the item with index 10 in `data`
# len(data) # returns the length/size of `data`
# ```
# We will return to why these are needed in the `DataLoader` wrapping class
#
# Now, to the actual implementation: The idea is to have the dataset class only store the filenames of the images (and the corresponding label), not the images themselves. We will find and store the filenames in the constructor. The `__getitem__` method will use the index to look up the correct filename and load it into memory.
# The `__len__` method is left for you to implement.
#
# Being able to use and understand code you have not written is an important ability. Below you are required to interact with the dataset class with a simple completion of the implementation and by extracting some data from the class. This is partly to ensure that you understand this specific class and partly to show you some tools for exploring new code.

# %%
from torch.utils.data import Dataset
from itertools import chain
from PIL import Image

class DogsCatsData(Dataset):
    
    def __init__(self, root, transform, dog_label=1, cat_label=0):
        """Constructor
        
        Args:
            root (Path/str): Filepath to the data root, e.g. './small_train'
            transform (Compose): A composition of image transforms, see below.
        """
        
        root = Path(root)
        if not (root.exists() and root.is_dir()):
            raise ValueError(f"Data root '{root}' is invalid")
            
        self.root = root
        self.transform = transform
        self._dog_label = dog_label
        self._cat_label = cat_label
        
        # Collect samples, both cat and dog and store pairs of (filepath, label) in a simple list.
        self._samples = self._collect_samples()
            
    def __getitem__(self, index):
        """Get sample by index
        
        Args:
            index (int)
        
        Returns:
             The index'th sample (Tensor, int)
        """
        # Access the stored path and label for the correct index
        path, label = self._samples[index]
        # Load the image into memory
        img = Image.open(path)
        # Perform transforms, if any.
        if self.transform is not None:
            img = self.transform(img)
        return img, label
    
    def __len__(self):
        """Total number of samples"""
        # YOUR CODE HERE
        return len(self._samples)
    
    def _collect_samples(self):
        """Collect all paths and labels
        
        Helper method for the constructor
        """
        # Iterator over dog filpath
        dog_paths = self._collect_imgs_sub_dir(self.root / "dogs")
        # Iterator of pairs (path, dog label)
        # Again, we use the `map` function to create an iterator. It's use is not as common as the so called
        # 'list comprehension' you've previously seen, but a good alternative to have seen.
        dog_paths_and_labels = map(lambda path: (path, self._dog_label), dog_paths)
        # Same for cats
        cat_paths = self._collect_imgs_sub_dir(self.root / "cats")
        cat_paths_and_labels = map(lambda path: (path, self._cat_label), cat_paths)
        # Sorting is not strictly necessary, but filesystem globbing (wildcard search) is not deterministic,
        # and consistency is nice when debugging.
        return sorted(list(chain(dog_paths_and_labels, cat_paths_and_labels)), key=lambda x: x[0].stem)
     
    @staticmethod
    def _collect_imgs_sub_dir(sub_dir: Path):
        """Collect image paths in a directory
        
        Helper method for the constructor
        """
        if not sub_dir.exists():
            raise ValueError(f"Data root '{self.root}' must contain sub dir '{sub_dir.name}'")
        return sub_dir.glob("*.jpg")
    
    def get_sample_by_id(self, id_):
        """Get sample by image id
        
        Convenience method for exploration.
        The indices does not correspond to the image id's in the filenames.
        Here is a (rather inefficient) way of inspecting a specific image.
        
        Args:
            id_ (str): Image id, e.g. `dog.321`
        """
        id_index = [path.stem for (path, _) in self._samples].index(id_)
        return self[id_index]

# %% [markdown]
# **(2 points)**
#
# Show that you understand the implementation by creating an instance called `example_dataset` of it. Create it from the small training set.
# Use the instance to
#  1. Print the number of samples in it
#  2. Print the label of the second sample, note that this is a number (0 or 1)

# %%
# The Dataset constructor has a transform attribute, we will cover it below. Just use this for now:
from torchvision.transforms import Compose, ToTensor
transform = Compose([ToTensor()])
# YOUR CODE HERE
example_dataset = DogsCatsData(root=small_train_path, transform=Compose([ToTensor()]))
print("Number of samples:", len(example_dataset))
_, label = example_dataset[1]
print("Label of the second sample:", label)
# Out:
# Number of samples: 3500
# Label of the second sample: 0

# %% [markdown]
# It is vital to explore your data, but it can be tricky to deal with images in the tensor format.
# To aid you, use the below helper function to visually inspect your images.

# %%
def display_image(axis, image_tensor):
    """Display a tensor as an image
    
    Args:
        axis (pyplot axis)
        image_tensor (torch.Tensor): tensor with shape (num_channels=3, width, heigth)
    """
    
    # See hint above
    if not isinstance(image_tensor, torch.Tensor):
        raise TypeError("The `display_image` function expects a `torch.Tensor` " +
                        "use the `ToTensor` transformation to convert the images to tensors.")
        
    # The imshow commands expects a `numpy array` with shape (3, width, height)
    # We rearrange the dimensions with `permute` and then convert it to `numpy`
    image_data = image_tensor.permute(1, 2, 0).numpy()
    height, width, _ = image_data.shape
    axis.imshow(image_data)
    axis.set_xlim(0, width)
    # By convention when working with images, the origin is at the top left corner.
    # Therefore, we switch the order of the y limits.
    axis.set_ylim(height, 0)

# Example usage
_, axis = plt.subplots()
some_random_index = 453
# Here we use the __getitem__ method as a "magic" method.
# Implementing it for a class, enables square bracket '[]' indexing
image_tensor, label = example_dataset[some_random_index]
display_image(axis, image_tensor)

# %% [markdown]
# ### 1.2 Preprocessing
# The `DogsCatsData` class constructor has an argument called `transform`. It allows us to transform or preprocess all the images in a batch, from the raw image data to a more suitable format. There are multiple motivations for preprocessing:
#
# - Some transformations might be needed to actually make the data work with our network (reshaping, permuting dimensions et c.).
# - Make the training more efficient by making the input dimensions smaller, e.g. resizing, cropping.
# - Artificially expanding the training data through [data augmentation](https://cartesianfaith.com/2016/10/06/what-you-need-to-know-about-data-augmentation-for-machine-learning/)
# - We have some clever idea of how to change the data to create a simpler optimisation problem.
#
# We do not expect you to do data augmentation, but feel free to preprocess the data as you see fit. Use the [documentation](https://pytorch.org/vision/stable/transforms.html#torchvision-transforms) to view available transforms. Extra important is the `Compose` transformation, which is a meta-transformation which composes actual ones, and the `ToTensor` transformation which is the simplest way to go from image to tensor format.
#
#
# Hints:
# - Revisit the `DogsCatsData` example usage to see how to use the `Compose` and `ToTensor` transformations.
# - When feeding the images to your CNN, you'll probably want all of them to have the same spatial size, even though the .jpeg files differ in this. Resizing the images can be done using the previously mentioned Pytorch Transforms.
# - Resizing the images to a smaller size while loading them can be beneficial as it speeds up training. The CNN's do surprisingly well on 64x64 or even 32x32 images. Shorter training cycles give you more time to experiment! Note: The VGG network used later in this assignment is specialised for images that are 224x224.
#
# We encourage you to explore the data and choose transformations that you believe to be useful. For exploration we provide you with a helper function to visually compare transformations side by side:

# %%
def compare_transforms(transformations, index):
    """Visually compare transformations side by side.
    Takes a list of DogsCatsData datasets with different compositions of transformations.
    It then display the `index`th image of the dataset for each transformed dataset in the list.
    
    Example usage:
        compare_transforms([dataset_with_transform_1, dataset_with_transform_2], 0)
    
    Args:
        transformations (list(DogsCatsData)): list of dataset instances with different transformations
        index (int): Index of the sample in the dataset you wish to compare.
    """
    
    # Here we combine two functions from basic python to validate the input to the function:
    # - `all` takes an iterable (something we can loop over, e.g. a list) of booleans
    #    and returns True if every element is True, otherwise it returns False.
    # - `isinstance` checks whether a variable is an instance of a particular type (class)
    if not all(isinstance(transf, Dataset) for transf in transformations):
        raise TypeError("All elements in the `transformations` list need to be of type Dataset")
        
    num_transformations = len(transformations)
    fig, axes = plt.subplots(1, num_transformations)
    
    # This is just a hack to make sure that `axes` is a list of the same length as `transformations`.
    # If we only have one element in the list, `plt.subplots` will not create a list of a single axis
    # but rather just an axis without a list.
    if num_transformations == 1:
        axes = [axes]
        
    for counter, (axis, transf) in enumerate(zip(axes, transformations)):
        axis.set_title(f"transf: {counter}")
        image_tensor = transf[index][0]
        display_image(axis, image_tensor)

    plt.show()

# %%
# Explore your dataset in this cell, you do not need to produce any results.
# YOUR CODE HERE
dataset_with_transform_1 = DogsCatsData(root=small_train_path, transform=transform)

transform2 = Compose([Resize((224, 224)), ToTensor()])
dataset_with_transform_2 = DogsCatsData(root=small_train_path, transform=transform2)
compare_transforms([dataset_with_transform_1, dataset_with_transform_2], 453)

# %% [markdown]
# **(2 points)**
#
# Normalisation of the training data is popular in pre-processing. What is the argument or intuition for why this is a beneficial transformation?

# %% [markdown]
# **Your answer:** (fill in here)
#
# 1. Improving the convergence speed and accuracy of the model and making the features of different dimensions numerically comparable can greatly improve the accuracy of the classifier.
# 2. Prevent model gradient explosion.
# 3. Increase numerical stability, make activation functions work more efficiently, and simplify the hyperparameter tuning process

# %% [markdown]
# ### 1.3 Data loaders
# With our dataset class implementation in place, creating a `DataLoader` instance is simple.
#
# The data loader class wraps the dataset and provides a way to iterate over batches in the training loop.
# To produce batches, it gets the total number of samples $N$ with the dataset's `__len__` method.
# It divides the indices $1, \dots, N$ into equally sized index batches with $B$ (batch size) elements. A particular batch with pairs of image and label is created by calling the dataset's `__getitem__` method with the indices in the batch. NB: the last batch in an epoch might be smaller if $N$ is not divisible by $B$.
#
# Create the data loaders needed for training (use the small version of the data), in the cell below.
# The `DataLoader` class is documented [here](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) , but it's not that much to it.
# You simply create a data loader with a dataset instance and some other (self-explanatory) settings:
#
# ```python
# train_dataloader = DataLoader(example_dataset, batch_size=batch_size, shuffle=True)
# ```
#
# **(1 point)**
#
# Create data loaders required for training and validation.
#
# Hints:
# - The specified `batch_size` should be chosen so that you train fast but don't run out of memory. You need to figure this out empirically; start small and increase the batch size until you run out of memory. Beyond this pragmatic approach, feel free to contribute to the highly contested scientific debate about the relation between batch size and generalisation.
# - The `DataLoader` constructor takes an optional argument `num_workers`, which defaults to `0` if not provided. Setting a higher number creates multiple threads which load batches concurrently. This can speed up training considerably.

# %%
# YOUR CODE HERE
transform = Compose([Resize((224, 224)), ToTensor()])
small_train = DogsCatsData(root=small_train_path, transform=transform)
small_val = DogsCatsData(root=small_val_path, transform=transform)
train = DogsCatsData(root=train_path, transform=transform)
val = DogsCatsData(root=val_path, transform=transform)

small_train_loader = DataLoader(small_train, batch_size=128, shuffle=True)
small_val_loader = DataLoader(small_val, batch_size=128, shuffle=False)
train_loader = DataLoader(train, batch_size=128, shuffle=True)
valid_loader = DataLoader(val, batch_size=128, shuffle=False)

# %% [markdown]
# ---
# ## 2. Training
#
# ### 2.1 The first model
#
# **(3 points)**
#
# Now, it's time to create a model called `FirstCnn`. To begin with, you have to create a CNN to an exact specification. After that, you will get the chance to be more creative.
#
# For the first model, create a network that:
# - Inherits from [`nn.Module`](https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module)
# - Implements a constructor `__init__(self, img_size)`, a `forward(self, input_batch)` method and whatever other helper methods you deem necessary. Note that a (square) image size should be a parameter in the model's constructor. While not strictly necessary, it is an acceptable way of handling varying input dim's and it is convenient for testing.
# - Can handle square images of arbitrary size and arbitrary large mini-batch sizes (within memory limits, of course). You may assume that there are always three colour channels, i.e., a mini-batch will have the shape `(batch size = B, num channels = 3, img size = D, D)`
# - Has layers:
#     1. Two convolutional layers, each with 10 filters, kernel size = 3, stride = 1, padding = 0
#     2. A single fully connected layer.
# - Related layers such as a pooling operation are optional.
# - Choose suitable activation functions
# - Outputs the probability of the image belonging to the class 'dog'. Technically the output should consist of `B` probabilities, one for each image in the mini-batch and so have the shape `(B,)`.
#
# Hints:
#
# - The subpage for [`torch.nn`](https://pytorch.org/docs/stable/nn.html) is a good place to find the layer specifics.
# - Going from the last CNN layer to the final fully connected layer is not trivial. The convolutions produces feature maps which we can think of as an image with many channels, while the fully connected layer expects a row vector as input. Calculate how many output neurons the convolutions produce and use `.reshape` to make your tensor fit the fully connected layer. It is also common to see the `.view` and `.squeeze` methods to do the same thing. They basically do the same thing (apart from some differences in internal memory management) but are less transparent. *Hint within the hint:* remember that the fully connected layers expects a *batch* of 1D tensors.

# %%
# YOUR CODE HERE
class FirstCnn(nn.Module):
    def __init__(self, img_size):
        super(FirstCnn, self).__init__()
        self.conv1 = nn.Conv2d(3, 10, kernel_size=3, stride=1, padding=0)
        self.conv2 = nn.Conv2d(10, 10, kernel_size=3, stride=1, padding=0)
        self.conv_size = (img_size - 4) * (img_size - 4) * 10
        self.full_connect = nn.Linear(self.conv_size, 1)
        self.relu = nn.ReLU()
        
    def forward(self, input_batch):
        x = self.relu(self.conv1(input_batch))
        x = self.relu(self.conv2(x))
        x = x.view(x.size(0), -1)
        x = self.full_connect(x)
        output = torch.sigmoid(x).squeeze()
        return output

# %%
def test_model(model_class):
    assert issubclass(model_class, nn.Module), "Model class should inherit from nn.Module"
    
    assert getattr(model_class, "forward", None) is not None, "Model class should have a 'forward' method"
    
    _test_output(model_class, some_img_size=224, some_batch_size=64)
    _test_output(model_class, some_img_size=32, some_batch_size=8)
    
    print("Test passed.")

def _test_output(model_class, some_img_size, some_batch_size):
    random_input = torch.rand(some_batch_size, 3, some_img_size, some_img_size)
    model_instance = model_class(img_size=some_img_size)
    output = model_instance.forward(random_input)
    output_shape = list(output.shape)
    assert output_shape == [some_batch_size], f"Expected output size [{some_batch_size}], got {output_shape}"
    
# Note that the test takes the actual class, not an instance of it, as input.
# Here, we assume that the model class is named 'FirstCnn'
test_model(FirstCnn)
# Out:
# Test passed.

# %% [markdown]
# **(3 points)**
#
# You have been told that one of the benefits of CNN is that it can handle input of different sizes. Yet, you needed to know the image size in the constructor.
# Explain how you made your model handle different input sizes and why it is necessary, despite it being a CNN.

# %% [markdown]
# **Your answer:**
# 1.  The input size to a fully connected layer (or linear layer) must be fixed.The **conv_size** was calculated in the constructor based on the **img_size**, which is resized to $224\times224$ by transformation when creating data loader.
# 2.  In order to do batch processing each input sample must have the same dimensions.
# 3.  Features are extracted consistently across varying sizes by resizing.

# %% [markdown]
# ### 2.2 The training loop
#
# **(1 point)**
#
# You have already seen quite a few training loops in the preparations. Below we provide you with an example of a basic one that you can use.
# You need to provide an implementation that maps network outputs (probabilites) to hard labels.
#
# An extra point is awarded if you provide a vectorised implementation.

# %%
def output_to_label(z):
    """Map network output z to a hard label {0, 1}
    
    Args:
        z (Tensor): Probabilities for each sample in a batch.
    Returns:
        c (Tensor): Hard label {0, 1} for each sample in a batch
    """
    # YOUR CODE HERE
    c = (z >= 0.5).long()
    return c
    
def test_output_to_label(fn):
    batch_size = torch.randint(1, 64, (1,))
    random_logits = torch.rand(batch_size)
    random_probs = random_logits / random_logits.sum()
    labels = fn(random_probs)
    assert labels.shape == random_logits.shape, "The element-wise function should preserve the shape"
    assert labels.dtype == torch.long, "Incorrect datatype, should be torch.long"
    fixed_logits = torch.tensor([0.1, 0.9, 0.51, 0.49, 0.7])
    fixed_labels = torch.tensor([0, 1, 1, 0, 1], dtype=torch.long)
    assert all(fixed_labels == fn(fixed_logits)), "Incorrect fixed output"
    assert fixed_logits.device == fixed_labels.device, "Make sure that the output tensor is on the same device"
    print("Test passed!")

test_output_to_label(output_to_label)
# Out:
# Test passed!

# %%
def training_loop(model, optimizer, loss_fn, train_loader, val_loader, num_epochs, print_every):
    print("Starting training")
    device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
    model.to(device)
    train_losses, train_accs, val_losses, val_accs = [], [], [], []

    for epoch in range(1, num_epochs+1):
        model, train_loss, train_acc = train_epoch(model,
                                                   optimizer,
                                                   loss_fn,
                                                   train_loader,
                                                   val_loader,
                                                   device,
                                                   print_every)
        val_loss, val_acc = validate(model, loss_fn, val_loader, device)
        print(f"Epoch {epoch}/{num_epochs}: "
              f"Train loss: {sum(train_loss)/len(train_loss):.3f}, "
              f"Train acc.: {sum(train_acc)/len(train_acc):.3f}, "
              f"Val. loss: {val_loss:.3f}, "
              f"Val. acc.: {val_acc:.3f}")
        train_losses.extend(train_loss)
        train_accs.extend(train_acc)
        val_losses.append(val_loss)
        val_accs.append(val_acc)
    return model, train_losses, train_accs, val_losses, val_accs

def train_epoch(model, optimizer, loss_fn, train_loader, val_loader, device, print_every):
    # Train:
    model.train()
    train_loss_batches, train_acc_batches = [], []
    num_batches = len(train_loader)
    for batch_index, (x, y) in enumerate(train_loader, 1):
        inputs, labels = x.to(device), y.to(device)
        optimizer.zero_grad()
        z = model.forward(inputs)
        loss = loss_fn(z, labels.float())
        loss.backward()
        optimizer.step()
        train_loss_batches.append(loss.item())

        hard_preds = output_to_label(z)
        acc_batch_avg = (hard_preds == labels).float().mean().item()
        train_acc_batches.append(acc_batch_avg)

        # If you want to print your progress more often than every epoch you can
        # set `print_every` to the number of batches you want between every status update.
        # Note that the print out will trigger a full validation on the full val. set => slows down training
        if print_every is not None and batch_index % print_every == 0:
            val_loss, val_acc = validate(model, loss_fn, val_loader, device)
            model.train()
            print(f"\tBatch {batch_index}/{num_batches}: "
                  f"\tTrain loss: {sum(train_loss_batches[-print_every:])/print_every:.3f}, "
                  f"\tTrain acc.: {sum(train_acc_batches[-print_every:])/print_every:.3f}, "
                  f"\tVal. loss: {val_loss:.3f}, "
                  f"\tVal. acc.: {val_acc:.3f}")

    return model, train_loss_batches, train_acc_batches

def validate(model, loss_fn, val_loader, device):
    val_loss_cum = 0
    val_acc_cum = 0
    model.eval()
    with torch.no_grad():
        for batch_index, (x, y) in enumerate(val_loader, 1):
            inputs, labels = x.to(device), y.to(device)
            z = model.forward(inputs)

            batch_loss = loss_fn(z, labels.float())
            val_loss_cum += batch_loss.item()
            hard_preds = output_to_label(z)
            acc_batch_avg = (hard_preds == labels).float().mean().item()
            val_acc_cum += acc_batch_avg
    return val_loss_cum/len(val_loader), val_acc_cum/len(val_loader)

# %% [markdown]
# **(1 point)**
#
# Use the training loop to train your model, using the two data loaders you created earlier. Train for a reasonable amount of epochs, so as to get a good sense of how well this architecture performs.
#
# Hints:
# - Training on a CPU is slow and in the beginning you just want to verify that your architecture actually produces a predicition with the correct shape. Make everything you can to speed up the prototyping phase, e.g. train only for a single epoch and make the images ridiculously small.

# %%
# YOUR CODE HERE

# hype parameters
img_size = 64
batch_size = 128
print_every = 7
num_epochs = 20
lr = 5e-4

transform = Compose([Resize((img_size, img_size)), ToTensor()])
small_train = DogsCatsData(root=small_train_path, transform=transform)
small_val = DogsCatsData(root=small_val_path, transform=transform)

small_train_loader = DataLoader(small_train, batch_size=batch_size, shuffle=True)
small_val_loader = DataLoader(small_val, batch_size=batch_size, shuffle=False)


model = FirstCnn(img_size=img_size)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

model, train_losses, train_accs, val_losses, val_accs = training_loop(
    model=model,
    optimizer=optimizer,
    loss_fn=criterion,
    train_loader=small_train_loader,  
    val_loader=small_val_loader,  
    num_epochs=num_epochs,
    print_every=print_every
)
# Out:
# Starting training
# 	Batch 7/28: 	Train loss: 0.711, 	Train acc.: 0.491, 	Val. loss: 0.704, 	Val. acc.: 0.512
# 	Batch 14/28: 	Train loss: 0.703, 	Train acc.: 0.513, 	Val. loss: 0.712, 	Val. acc.: 0.488
# 	Batch 21/28: 	Train loss: 0.708, 	Train acc.: 0.490, 	Val. loss: 0.701, 	Val. acc.: 0.512
# 	Batch 28/28: 	Train loss: 0.702, 	Train acc.: 0.490, 	Val. loss: 0.701, 	Val. acc.: 0.488
# Epoch 1/20: Train loss: 0.706, Train acc.: 0.496, Val. loss: 0.701, Val. acc.: 0.488
# 	Batch 7/28: 	Train loss: 0.692, 	Train acc.: 0.518, 	Val. loss: 0.689, 	Val. acc.: 0.547
# 	Batch 14/28: 	Train loss: 0.688, 	Train acc.: 0.522, 	Val. loss: 0.686, 	Val. acc.: 0.586
# 	Batch 21/28: 	Train loss: 0.684, 	Train acc.: 0.614, 	Val. loss: 0.686, 	Val. acc.: 0.567
# 	Batch 28/28: 	Train loss: 0.682, 	Train acc.: 0.590, 	Val. loss: 0.685, 	Val. acc.: 0.569
# Epoch 2/20: Train loss: 0.686, Train acc.: 0.561, Val. loss: 0.685, Val. acc.: 0.569
# 	Batch 7/28: 	Train loss: 0.676, 	Train acc.: 0.614, 	Val. loss: 0.682, 	Val. acc.: 0.562
# 	Batch 14/28: 	Train loss: 0.674, 	Train acc.: 0.593, 	Val. loss: 0.678, 	Val. acc.: 0.583
# 	Batch 21/28: 	Train loss: 0.668, 	Train acc.: 0.610, 	Val. loss: 0.675, 	Val. acc.: 0.569
# 	Batch 28/28: 	Train loss: 0.670, 	Train acc.: 0.610, 	Val. loss: 0.682, 	Val. acc.: 0.540
# Epoch 3/20: Train loss: 0.672, Train acc.: 0.607, Val. loss: 0.682, Val. acc.: 0.540
# 	Batch 7/28: 	Train loss: 0.663, 	Train acc.: 0.587, 	Val. loss: 0.669, 	Val. acc.: 0.595
# 	Batch 14/28: 	Train loss: 0.662, 	Train acc.: 0.627, 	Val. loss: 0.663, 	Val. acc.: 0.636
# 	Batch 21/28: 	Train loss: 0.649, 	Train acc.: 0.662, 	Val. loss: 0.663, 	Val. acc.: 0.612
# 	Batch 28/28: 	Train loss: 0.655, 	Train acc.: 0.628, 	Val. loss: 0.663, 	Val. acc.: 0.616
# Epoch 4/20: Train loss: 0.657, Train acc.: 0.626, Val. loss: 0.663, Val. acc.: 0.616
# 	Batch 7/28: 	Train loss: 0.646, 	Train acc.: 0.633, 	Val. loss: 0.657, 	Val. acc.: 0.620
# 	Batch 14/28: 	Train loss: 0.627, 	Train acc.: 0.694, 	Val. loss: 0.648, 	Val. acc.: 0.649
# 	Batch 21/28: 	Train loss: 0.636, 	Train acc.: 0.656, 	Val. loss: 0.647, 	Val. acc.: 0.644
# 	Batch 28/28: 	Train loss: 0.625, 	Train acc.: 0.669, 	Val. loss: 0.639, 	Val. acc.: 0.655
# Epoch 5/20: Train loss: 0.634, Train acc.: 0.663, Val. loss: 0.639, Val. acc.: 0.655
# 	Batch 7/28: 	Train loss: 0.624, 	Train acc.: 0.670, 	Val. loss: 0.637, 	Val. acc.: 0.653
# 	Batch 14/28: 	Train loss: 0.620, 	Train acc.: 0.675, 	Val. loss: 0.646, 	Val. acc.: 0.621
# 	Batch 21/28: 	Train loss: 0.619, 	Train acc.: 0.657, 	Val. loss: 0.631, 	Val. acc.: 0.662
# 	Batch 28/28: 	Train loss: 0.610, 	Train acc.: 0.684, 	Val. loss: 0.637, 	Val. acc.: 0.636
# Epoch 6/20: Train loss: 0.618, Train acc.: 0.672, Val. loss: 0.637, Val. acc.: 0.636
# 	Batch 7/28: 	Train loss: 0.606, 	Train acc.: 0.674, 	Val. loss: 0.633, 	Val. acc.: 0.651
# 	Batch 14/28: 	Train loss: 0.601, 	Train acc.: 0.708, 	Val. loss: 0.624, 	Val. acc.: 0.673
# 	Batch 21/28: 	Train loss: 0.600, 	Train acc.: 0.675, 	Val. loss: 0.628, 	Val. acc.: 0.654
# 	Batch 28/28: 	Train loss: 0.601, 	Train acc.: 0.675, 	Val. loss: 0.633, 	Val. acc.: 0.638
# Epoch 7/20: Train loss: 0.602, Train acc.: 0.683, Val. loss: 0.633, Val. acc.: 0.638
# 	Batch 7/28: 	Train loss: 0.599, 	Train acc.: 0.673, 	Val. loss: 0.643, 	Val. acc.: 0.623
# 	Batch 14/28: 	Train loss: 0.603, 	Train acc.: 0.671, 	Val. loss: 0.646, 	Val. acc.: 0.627
# 	Batch 21/28: 	Train loss: 0.589, 	Train acc.: 0.684, 	Val. loss: 0.624, 	Val. acc.: 0.665
# 	Batch 28/28: 	Train loss: 0.589, 	Train acc.: 0.687, 	Val. loss: 0.616, 	Val. acc.: 0.664
# Epoch 8/20: Train loss: 0.595, Train acc.: 0.679, Val. loss: 0.616, Val. acc.: 0.664
# 	Batch 7/28: 	Train loss: 0.585, 	Train acc.: 0.704, 	Val. loss: 0.615, 	Val. acc.: 0.677
# 	Batch 14/28: 	Train loss: 0.574, 	Train acc.: 0.714, 	Val. loss: 0.624, 	Val. acc.: 0.659
# 	Batch 21/28: 	Train loss: 0.575, 	Train acc.: 0.704, 	Val. loss: 0.616, 	Val. acc.: 0.670
# 	Batch 28/28: 	Train loss: 0.605, 	Train acc.: 0.694, 	Val. loss: 0.610, 	Val. acc.: 0.676
# Epoch 9/20: Train loss: 0.585, Train acc.: 0.704, Val. loss: 0.610, Val. acc.: 0.676
# 	Batch 7/28: 	Train loss: 0.578, 	Train acc.: 0.702, 	Val. loss: 0.612, 	Val. acc.: 0.681
# 	Batch 14/28: 	Train loss: 0.573, 	Train acc.: 0.713, 	Val. loss: 0.611, 	Val. acc.: 0.673
# 	Batch 21/28: 	Train loss: 0.553, 	Train acc.: 0.730, 	Val. loss: 0.608, 	Val. acc.: 0.682
# 	Batch 28/28: 	Train loss: 0.551, 	Train acc.: 0.744, 	Val. loss: 0.614, 	Val. acc.: 0.676
# Epoch 10/20: Train loss: 0.564, Train acc.: 0.722, Val. loss: 0.614, Val. acc.: 0.676
# 	Batch 7/28: 	Train loss: 0.564, 	Train acc.: 0.719, 	Val. loss: 0.611, 	Val. acc.: 0.672
# 	Batch 14/28: 	Train loss: 0.570, 	Train acc.: 0.712, 	Val. loss: 0.605, 	Val. acc.: 0.687
# 	Batch 21/28: 	Train loss: 0.546, 	Train acc.: 0.729, 	Val. loss: 0.655, 	Val. acc.: 0.626
# 	Batch 28/28: 	Train loss: 0.562, 	Train acc.: 0.699, 	Val. loss: 0.625, 	Val. acc.: 0.654
# Epoch 11/20: Train loss: 0.560, Train acc.: 0.715, Val. loss: 0.625, Val. acc.: 0.654
# 	Batch 7/28: 	Train loss: 0.548, 	Train acc.: 0.746, 	Val. loss: 0.615, 	Val. acc.: 0.669
# 	Batch 14/28: 	Train loss: 0.559, 	Train acc.: 0.735, 	Val. loss: 0.608, 	Val. acc.: 0.674
# 	Batch 21/28: 	Train loss: 0.555, 	Train acc.: 0.723, 	Val. loss: 0.606, 	Val. acc.: 0.679
# 	Batch 28/28: 	Train loss: 0.540, 	Train acc.: 0.724, 	Val. loss: 0.606, 	Val. acc.: 0.681
# Epoch 12/20: Train loss: 0.551, Train acc.: 0.732, Val. loss: 0.606, Val. acc.: 0.681
# 	Batch 7/28: 	Train loss: 0.530, 	Train acc.: 0.756, 	Val. loss: 0.612, 	Val. acc.: 0.677
# 	Batch 14/28: 	Train loss: 0.550, 	Train acc.: 0.734, 	Val. loss: 0.604, 	Val. acc.: 0.680
# 	Batch 21/28: 	Train loss: 0.522, 	Train acc.: 0.748, 	Val. loss: 0.607, 	Val. acc.: 0.676
# 	Batch 28/28: 	Train loss: 0.544, 	Train acc.: 0.739, 	Val. loss: 0.608, 	Val. acc.: 0.684
# Epoch 13/20: Train loss: 0.536, Train acc.: 0.744, Val. loss: 0.608, Val. acc.: 0.684
# 	Batch 7/28: 	Train loss: 0.525, 	Train acc.: 0.760, 	Val. loss: 0.633, 	Val. acc.: 0.652
# 	Batch 14/28: 	Train loss: 0.559, 	Train acc.: 0.720, 	Val. loss: 0.604, 	Val. acc.: 0.687
# 	Batch 21/28: 	Train loss: 0.532, 	Train acc.: 0.735, 	Val. loss: 0.608, 	Val. acc.: 0.667
# 	Batch 28/28: 	Train loss: 0.515, 	Train acc.: 0.766, 	Val. loss: 0.609, 	Val. acc.: 0.689
# Epoch 14/20: Train loss: 0.533, Train acc.: 0.745, Val. loss: 0.609, Val. acc.: 0.689
# 	Batch 7/28: 	Train loss: 0.517, 	Train acc.: 0.747, 	Val. loss: 0.608, 	Val. acc.: 0.687
# 	Batch 14/28: 	Train loss: 0.505, 	Train acc.: 0.772, 	Val. loss: 0.601, 	Val. acc.: 0.686
# 	Batch 21/28: 	Train loss: 0.532, 	Train acc.: 0.728, 	Val. loss: 0.607, 	Val. acc.: 0.683
# 	Batch 28/28: 	Train loss: 0.528, 	Train acc.: 0.737, 	Val. loss: 0.629, 	Val. acc.: 0.671
# Epoch 15/20: Train loss: 0.521, Train acc.: 0.746, Val. loss: 0.629, Val. acc.: 0.671
# 	Batch 7/28: 	Train loss: 0.510, 	Train acc.: 0.757, 	Val. loss: 0.606, 	Val. acc.: 0.690
# 	Batch 14/28: 	Train loss: 0.496, 	Train acc.: 0.780, 	Val. loss: 0.611, 	Val. acc.: 0.676
# 	Batch 21/28: 	Train loss: 0.492, 	Train acc.: 0.780, 	Val. loss: 0.609, 	Val. acc.: 0.682
# 	Batch 28/28: 	Train loss: 0.536, 	Train acc.: 0.738, 	Val. loss: 0.612, 	Val. acc.: 0.684
# Epoch 16/20: Train loss: 0.509, Train acc.: 0.764, Val. loss: 0.612, Val. acc.: 0.684
# 	Batch 7/28: 	Train loss: 0.504, 	Train acc.: 0.769, 	Val. loss: 0.613, 	Val. acc.: 0.678
# 	Batch 14/28: 	Train loss: 0.507, 	Train acc.: 0.769, 	Val. loss: 0.605, 	Val. acc.: 0.680
# 	Batch 21/28: 	Train loss: 0.480, 	Train acc.: 0.799, 	Val. loss: 0.605, 	Val. acc.: 0.685
# 	Batch 28/28: 	Train loss: 0.509, 	Train acc.: 0.752, 	Val. loss: 0.634, 	Val. acc.: 0.666
# Epoch 17/20: Train loss: 0.500, Train acc.: 0.772, Val. loss: 0.634, Val. acc.: 0.666
# 	Batch 7/28: 	Train loss: 0.522, 	Train acc.: 0.758, 	Val. loss: 0.620, 	Val. acc.: 0.679
# 	Batch 14/28: 	Train loss: 0.498, 	Train acc.: 0.758, 	Val. loss: 0.612, 	Val. acc.: 0.673
# 	Batch 21/28: 	Train loss: 0.468, 	Train acc.: 0.798, 	Val. loss: 0.603, 	Val. acc.: 0.684
# 	Batch 28/28: 	Train loss: 0.491, 	Train acc.: 0.772, 	Val. loss: 0.637, 	Val. acc.: 0.663
# Epoch 18/20: Train loss: 0.495, Train acc.: 0.771, Val. loss: 0.637, Val. acc.: 0.663
# 	Batch 7/28: 	Train loss: 0.490, 	Train acc.: 0.773, 	Val. loss: 0.609, 	Val. acc.: 0.680
# 	Batch 14/28: 	Train loss: 0.500, 	Train acc.: 0.749, 	Val. loss: 0.629, 	Val. acc.: 0.666
# 	Batch 21/28: 	Train loss: 0.497, 	Train acc.: 0.768, 	Val. loss: 0.615, 	Val. acc.: 0.683
# 	Batch 28/28: 	Train loss: 0.480, 	Train acc.: 0.788, 	Val. loss: 0.614, 	Val. acc.: 0.684
# Epoch 19/20: Train loss: 0.492, Train acc.: 0.770, Val. loss: 0.614, Val. acc.: 0.684
# 	Batch 7/28: 	Train loss: 0.476, 	Train acc.: 0.800, 	Val. loss: 0.609, 	Val. acc.: 0.674
# 	Batch 14/28: 	Train loss: 0.460, 	Train acc.: 0.808, 	Val. loss: 0.611, 	Val. acc.: 0.678
# 	Batch 21/28: 	Train loss: 0.492, 	Train acc.: 0.775, 	Val. loss: 0.623, 	Val. acc.: 0.674
# 	Batch 28/28: 	Train loss: 0.478, 	Train acc.: 0.766, 	Val. loss: 0.636, 	Val. acc.: 0.663
# Epoch 20/20: Train loss: 0.476, Train acc.: 0.787, Val. loss: 0.636, Val. acc.: 0.663

# %% [markdown]
# ### 2.3 Visualisation
#
# **(1 point)**
#
# Create two plots. In one of them, plot the loss in the training and the validation datasets. In the other one, plot the accuracy in the training and validation datasets.
# Note that the given training loop produces metrics at different intervals for training and validation, make sure that you align your metrics in a way that makes sense.

# %%
# YOUR CODE HERE
sns.set_context("talk")
sns.set_palette("husl")

def visual(train, val, test_name):
    plt.figure(figsize=(12, 10))
    train_x = np.linspace(0, num_epochs, len(train))
    val_x = np.linspace(0, num_epochs, len(val))
    plt.plot(train_x, train, label=f'Training {test_name}', linewidth=2, linestyle='-')
    plt.plot(val_x, val, label=f'Validation {test_name}', linewidth=2, linestyle='--')
    plt.legend(frameon=False)
    plt.title(f'Training and Validation {test_name}')
    plt.xlabel('Epochs')
    plt.ylabel(test_name)
    sns.despine()
    plt.show()

visual(train_losses, val_losses, 'Loss')
visual(train_accs, val_accs, 'Accuracy')

# %% [markdown]
# **(2 points)**
#
# Based on these, what would you suggest for improving your model? Why?

# %% [markdown]
# **Your answer:** (fill in here)
# 1. Enhance the training data by techniques like rotation, flipping, etc., to make the model more robust.
# 2. Adjust the learning rate, batch size and other hyperparameters
# 3. Use more complex models: Consider using network models with more layers or more nodes.
# 4. When the verification loss no longer decreases, stop training to prevent overfitting.
# 5. Use techniques such as Dropout or L2 regularization to reduce overfitting.

# %% [markdown]
# [Save your model](https://pytorch.org/tutorials/beginner/saving_loading_models.html) to disk (the architecture, weights, optimizer state, losses and accuracies). This is simply so you can use it again easily in the later parts of the notebook, without having to keep it in memory or re-training it. The actual file you create is not relevant to your submission. The code to save the model is given in the cell below.

# %%
# Assuming that you named your model "first_model"
torch.save({'model_state_dict': model.state_dict(),
            'train_losses': train_losses,
            'train_accs': train_accs,
            'val_losses': val_losses,
            'val_accs': val_accs,
            }, "./first_model.ckpt")

# Example of creating and initialising model with a previously saved state dict:
saved_first_model = FirstCnn(img_size=img_size) # fill-in the arguments if needed
checkpoint = torch.load("first_model.ckpt")
saved_first_model.load_state_dict(checkpoint['model_state_dict'])

# Example of re-using saved statistics:
print("Validation accuracies:", checkpoint['val_accs'])
# Out:
# Validation accuracies: [0.48828125, 0.569067028661569, 0.539770153661569, 0.6157155781984329, 0.6550894478956858, 0.635784645875295, 0.6380774478117625, 0.6644870936870575, 0.6755264947811762, 0.6761492292086283, 0.6536175260941187, 0.6809895833333334, 0.6843863228956858, 0.6889153073231379, 0.6707993696133295, 0.68359375, 0.66584579149882, 0.662958562374115, 0.6839334269364675, 0.6629868696133295]

# %% [markdown]
# ---
# ## 3. Improving your model

# %% [markdown]
# **(3 points)**
#
# Now you are free to create whichever model you want. A simple improvement based on your analysis of the above results is fine, or you can do something more ambitious. When you're happy with one architecture, copy it in the cell below and train it here. Save the training and validation losses and accuracies. You'll use this later to compare your best model with the one using transfer learning. *Hint*: reducing the input image size facilitates training.
#
# **Note**: When trying different ideas, you'll end up with several different models. However, when submitting your solutions to Canvas, the cell below must contain only the definition and training of *one* model. Remove all code related to the models that were not chosen.

# %%
# YOUR CODE HERE
class ImprovedCnn(nn.Module):
    def __init__(self, img_size):
        super(ImprovedCnn, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.batch_norm1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.batch_norm2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.batch_norm3 = nn.BatchNorm2d(64)
        self.dropout = nn.Dropout(0.5)
        self.pool = nn.MaxPool2d(2, 2)
        self.relu = nn.ReLU()
        x = torch.randn(1, 3, img_size, img_size)
        x = self._forward_features(x)
        num_flatten = x.numel()
        self.fc1 = nn.Linear(num_flatten, 128)
        self.fc2 = nn.Linear(128, 1)
        

    def _forward_features(self, x):
        x = self.pool(self.relu(self.batch_norm1(self.conv1(x))))
        x = self.pool(self.relu(self.batch_norm2(self.conv2(x))))
        x = self.pool(self.relu(self.batch_norm3(self.conv3(x))))
        return x

    def forward(self, x):
        x = self._forward_features(x)
        x = x.view(x.size(0), -1)
        x = self.dropout(self.relu(self.fc1(x)))
        x = torch.sigmoid(self.fc2(x)).squeeze()
        return x

img_size = 64
batch_size = 128
print_every = 7
num_epochs = 20
lr = 1e-3

transform2 = Compose([Resize((img_size, img_size)), ToTensor()])
small_train = DogsCatsData(root=small_train_path, transform=transform2)
small_val = DogsCatsData(root=small_val_path, transform=transform2)

small_train_loader = DataLoader(small_train, batch_size=batch_size, shuffle=True)
small_val_loader = DataLoader(small_val, batch_size=batch_size, shuffle=False)

model_im = ImprovedCnn(img_size=img_size)
criterion = nn.BCELoss()
optimizer = optim.Adam(model_im.parameters(), lr=lr)

model_im, train_losses_im, train_accs_im, val_losses_im, val_accs_im = training_loop(
    model=model_im,
    optimizer=optimizer,
    loss_fn=criterion,
    train_loader=small_train_loader,  
    val_loader=small_val_loader,  
    num_epochs=num_epochs,
    print_every=print_every
)
# Out:
# Starting training
# 	Batch 7/28: 	Train loss: 1.090, 	Train acc.: 0.501, 	Val. loss: 0.691, 	Val. acc.: 0.550
# 	Batch 14/28: 	Train loss: 0.769, 	Train acc.: 0.551, 	Val. loss: 0.694, 	Val. acc.: 0.483
# 	Batch 21/28: 	Train loss: 0.709, 	Train acc.: 0.539, 	Val. loss: 0.686, 	Val. acc.: 0.573
# 	Batch 28/28: 	Train loss: 0.681, 	Train acc.: 0.545, 	Val. loss: 0.690, 	Val. acc.: 0.490
# Epoch 1/20: Train loss: 0.812, Train acc.: 0.534, Val. loss: 0.690, Val. acc.: 0.490
# 	Batch 7/28: 	Train loss: 0.664, 	Train acc.: 0.617, 	Val. loss: 0.677, 	Val. acc.: 0.607
# 	Batch 14/28: 	Train loss: 0.640, 	Train acc.: 0.653, 	Val. loss: 0.667, 	Val. acc.: 0.603
# 	Batch 21/28: 	Train loss: 0.650, 	Train acc.: 0.599, 	Val. loss: 0.669, 	Val. acc.: 0.573
# 	Batch 28/28: 	Train loss: 0.636, 	Train acc.: 0.649, 	Val. loss: 0.696, 	Val. acc.: 0.531
# Epoch 2/20: Train loss: 0.647, Train acc.: 0.630, Val. loss: 0.696, Val. acc.: 0.531
# 	Batch 7/28: 	Train loss: 0.647, 	Train acc.: 0.642, 	Val. loss: 0.647, 	Val. acc.: 0.608
# 	Batch 14/28: 	Train loss: 0.626, 	Train acc.: 0.665, 	Val. loss: 0.649, 	Val. acc.: 0.601
# 	Batch 21/28: 	Train loss: 0.605, 	Train acc.: 0.677, 	Val. loss: 0.619, 	Val. acc.: 0.658
# 	Batch 28/28: 	Train loss: 0.608, 	Train acc.: 0.685, 	Val. loss: 0.598, 	Val. acc.: 0.675
# Epoch 3/20: Train loss: 0.621, Train acc.: 0.667, Val. loss: 0.598, Val. acc.: 0.675
# 	Batch 7/28: 	Train loss: 0.601, 	Train acc.: 0.686, 	Val. loss: 0.586, 	Val. acc.: 0.684
# 	Batch 14/28: 	Train loss: 0.559, 	Train acc.: 0.717, 	Val. loss: 0.578, 	Val. acc.: 0.702
# 	Batch 21/28: 	Train loss: 0.568, 	Train acc.: 0.728, 	Val. loss: 0.553, 	Val. acc.: 0.712
# 	Batch 28/28: 	Train loss: 0.580, 	Train acc.: 0.679, 	Val. loss: 0.596, 	Val. acc.: 0.670
# Epoch 4/20: Train loss: 0.577, Train acc.: 0.702, Val. loss: 0.596, Val. acc.: 0.670
# 	Batch 7/28: 	Train loss: 0.558, 	Train acc.: 0.720, 	Val. loss: 0.579, 	Val. acc.: 0.699
# 	Batch 14/28: 	Train loss: 0.551, 	Train acc.: 0.722, 	Val. loss: 0.552, 	Val. acc.: 0.711
# 	Batch 21/28: 	Train loss: 0.568, 	Train acc.: 0.712, 	Val. loss: 0.577, 	Val. acc.: 0.700
# 	Batch 28/28: 	Train loss: 0.552, 	Train acc.: 0.718, 	Val. loss: 0.537, 	Val. acc.: 0.735
# Epoch 5/20: Train loss: 0.557, Train acc.: 0.718, Val. loss: 0.537, Val. acc.: 0.735
# 	Batch 7/28: 	Train loss: 0.523, 	Train acc.: 0.747, 	Val. loss: 0.720, 	Val. acc.: 0.638
# 	Batch 14/28: 	Train loss: 0.543, 	Train acc.: 0.741, 	Val. loss: 0.546, 	Val. acc.: 0.726
# 	Batch 21/28: 	Train loss: 0.525, 	Train acc.: 0.731, 	Val. loss: 0.630, 	Val. acc.: 0.653
# 	Batch 28/28: 	Train loss: 0.515, 	Train acc.: 0.749, 	Val. loss: 0.534, 	Val. acc.: 0.737
# Epoch 6/20: Train loss: 0.526, Train acc.: 0.742, Val. loss: 0.534, Val. acc.: 0.737
# 	Batch 7/28: 	Train loss: 0.482, 	Train acc.: 0.763, 	Val. loss: 0.509, 	Val. acc.: 0.752
# 	Batch 14/28: 	Train loss: 0.490, 	Train acc.: 0.783, 	Val. loss: 0.697, 	Val. acc.: 0.641
# 	Batch 21/28: 	Train loss: 0.518, 	Train acc.: 0.749, 	Val. loss: 0.513, 	Val. acc.: 0.733
# 	Batch 28/28: 	Train loss: 0.528, 	Train acc.: 0.715, 	Val. loss: 0.664, 	Val. acc.: 0.642
# Epoch 7/20: Train loss: 0.505, Train acc.: 0.753, Val. loss: 0.664, Val. acc.: 0.642
# 	Batch 7/28: 	Train loss: 0.485, 	Train acc.: 0.753, 	Val. loss: 0.533, 	Val. acc.: 0.736
# 	Batch 14/28: 	Train loss: 0.480, 	Train acc.: 0.763, 	Val. loss: 0.502, 	Val. acc.: 0.751
# 	Batch 21/28: 	Train loss: 0.475, 	Train acc.: 0.770, 	Val. loss: 0.520, 	Val. acc.: 0.736
# 	Batch 28/28: 	Train loss: 0.458, 	Train acc.: 0.776, 	Val. loss: 0.491, 	Val. acc.: 0.757
# Epoch 8/20: Train loss: 0.474, Train acc.: 0.766, Val. loss: 0.491, Val. acc.: 0.757
# 	Batch 7/28: 	Train loss: 0.462, 	Train acc.: 0.788, 	Val. loss: 0.546, 	Val. acc.: 0.741
# 	Batch 14/28: 	Train loss: 0.449, 	Train acc.: 0.790, 	Val. loss: 0.484, 	Val. acc.: 0.754
# 	Batch 21/28: 	Train loss: 0.470, 	Train acc.: 0.763, 	Val. loss: 0.501, 	Val. acc.: 0.748
# 	Batch 28/28: 	Train loss: 0.411, 	Train acc.: 0.810, 	Val. loss: 0.466, 	Val. acc.: 0.778
# Epoch 9/20: Train loss: 0.448, Train acc.: 0.788, Val. loss: 0.466, Val. acc.: 0.778
# 	Batch 7/28: 	Train loss: 0.419, 	Train acc.: 0.819, 	Val. loss: 0.543, 	Val. acc.: 0.735
# 	Batch 14/28: 	Train loss: 0.420, 	Train acc.: 0.808, 	Val. loss: 0.453, 	Val. acc.: 0.782
# 	Batch 21/28: 	Train loss: 0.437, 	Train acc.: 0.796, 	Val. loss: 0.520, 	Val. acc.: 0.739
# 	Batch 28/28: 	Train loss: 0.413, 	Train acc.: 0.805, 	Val. loss: 0.482, 	Val. acc.: 0.766
# Epoch 10/20: Train loss: 0.422, Train acc.: 0.807, Val. loss: 0.482, Val. acc.: 0.766
# 	Batch 7/28: 	Train loss: 0.406, 	Train acc.: 0.808, 	Val. loss: 0.455, 	Val. acc.: 0.776
# 	Batch 14/28: 	Train loss: 0.396, 	Train acc.: 0.820, 	Val. loss: 0.674, 	Val. acc.: 0.683
# 	Batch 21/28: 	Train loss: 0.390, 	Train acc.: 0.809, 	Val. loss: 0.450, 	Val. acc.: 0.782
# 	Batch 28/28: 	Train loss: 0.367, 	Train acc.: 0.848, 	Val. loss: 0.578, 	Val. acc.: 0.715
# Epoch 11/20: Train loss: 0.390, Train acc.: 0.821, Val. loss: 0.578, Val. acc.: 0.715
# 	Batch 7/28: 	Train loss: 0.367, 	Train acc.: 0.830, 	Val. loss: 0.511, 	Val. acc.: 0.772
# 	Batch 14/28: 	Train loss: 0.384, 	Train acc.: 0.818, 	Val. loss: 0.483, 	Val. acc.: 0.753
# 	Batch 21/28: 	Train loss: 0.396, 	Train acc.: 0.833, 	Val. loss: 0.548, 	Val. acc.: 0.718
# 	Batch 28/28: 	Train loss: 0.425, 	Train acc.: 0.794, 	Val. loss: 0.566, 	Val. acc.: 0.730
# Epoch 12/20: Train loss: 0.393, Train acc.: 0.819, Val. loss: 0.566, Val. acc.: 0.730
# 	Batch 7/28: 	Train loss: 0.396, 	Train acc.: 0.828, 	Val. loss: 0.450, 	Val. acc.: 0.786
# 	Batch 14/28: 	Train loss: 0.360, 	Train acc.: 0.848, 	Val. loss: 0.426, 	Val. acc.: 0.808
# 	Batch 21/28: 	Train loss: 0.356, 	Train acc.: 0.843, 	Val. loss: 0.460, 	Val. acc.: 0.786
# 	Batch 28/28: 	Train loss: 0.340, 	Train acc.: 0.853, 	Val. loss: 0.591, 	Val. acc.: 0.731
# Epoch 13/20: Train loss: 0.363, Train acc.: 0.843, Val. loss: 0.591, Val. acc.: 0.731
# 	Batch 7/28: 	Train loss: 0.327, 	Train acc.: 0.857, 	Val. loss: 0.431, 	Val. acc.: 0.809
# 	Batch 14/28: 	Train loss: 0.386, 	Train acc.: 0.824, 	Val. loss: 0.457, 	Val. acc.: 0.793
# 	Batch 21/28: 	Train loss: 0.325, 	Train acc.: 0.874, 	Val. loss: 0.536, 	Val. acc.: 0.730
# 	Batch 28/28: 	Train loss: 0.363, 	Train acc.: 0.840, 	Val. loss: 0.473, 	Val. acc.: 0.788
# Epoch 14/20: Train loss: 0.350, Train acc.: 0.849, Val. loss: 0.473, Val. acc.: 0.788
# 	Batch 7/28: 	Train loss: 0.307, 	Train acc.: 0.874, 	Val. loss: 0.432, 	Val. acc.: 0.800
# 	Batch 14/28: 	Train loss: 0.324, 	Train acc.: 0.853, 	Val. loss: 0.434, 	Val. acc.: 0.804
# 	Batch 21/28: 	Train loss: 0.334, 	Train acc.: 0.858, 	Val. loss: 0.521, 	Val. acc.: 0.778
# 	Batch 28/28: 	Train loss: 0.327, 	Train acc.: 0.851, 	Val. loss: 0.555, 	Val. acc.: 0.755
# Epoch 15/20: Train loss: 0.323, Train acc.: 0.859, Val. loss: 0.555, Val. acc.: 0.755
# 	Batch 7/28: 	Train loss: 0.302, 	Train acc.: 0.874, 	Val. loss: 0.710, 	Val. acc.: 0.714
# 	Batch 14/28: 	Train loss: 0.265, 	Train acc.: 0.885, 	Val. loss: 0.510, 	Val. acc.: 0.789
# 	Batch 21/28: 	Train loss: 0.338, 	Train acc.: 0.852, 	Val. loss: 0.545, 	Val. acc.: 0.750
# 	Batch 28/28: 	Train loss: 0.286, 	Train acc.: 0.881, 	Val. loss: 0.455, 	Val. acc.: 0.795
# Epoch 16/20: Train loss: 0.298, Train acc.: 0.873, Val. loss: 0.455, Val. acc.: 0.795
# 	Batch 7/28: 	Train loss: 0.311, 	Train acc.: 0.857, 	Val. loss: 0.503, 	Val. acc.: 0.769
# 	Batch 14/28: 	Train loss: 0.279, 	Train acc.: 0.881, 	Val. loss: 0.440, 	Val. acc.: 0.798
# 	Batch 21/28: 	Train loss: 0.280, 	Train acc.: 0.874, 	Val. loss: 0.591, 	Val. acc.: 0.745
# 	Batch 28/28: 	Train loss: 0.282, 	Train acc.: 0.884, 	Val. loss: 0.458, 	Val. acc.: 0.800
# Epoch 17/20: Train loss: 0.288, Train acc.: 0.874, Val. loss: 0.458, Val. acc.: 0.800
# 	Batch 7/28: 	Train loss: 0.251, 	Train acc.: 0.894, 	Val. loss: 0.441, 	Val. acc.: 0.812
# 	Batch 14/28: 	Train loss: 0.252, 	Train acc.: 0.894, 	Val. loss: 0.847, 	Val. acc.: 0.708
# 	Batch 21/28: 	Train loss: 0.244, 	Train acc.: 0.894, 	Val. loss: 0.520, 	Val. acc.: 0.791
# 	Batch 28/28: 	Train loss: 0.265, 	Train acc.: 0.890, 	Val. loss: 0.573, 	Val. acc.: 0.750
# Epoch 18/20: Train loss: 0.253, Train acc.: 0.893, Val. loss: 0.573, Val. acc.: 0.750
# 	Batch 7/28: 	Train loss: 0.237, 	Train acc.: 0.903, 	Val. loss: 0.700, 	Val. acc.: 0.736
# 	Batch 14/28: 	Train loss: 0.248, 	Train acc.: 0.885, 	Val. loss: 0.714, 	Val. acc.: 0.735
# 	Batch 21/28: 	Train loss: 0.237, 	Train acc.: 0.912, 	Val. loss: 0.471, 	Val. acc.: 0.804
# 	Batch 28/28: 	Train loss: 0.228, 	Train acc.: 0.904, 	Val. loss: 0.434, 	Val. acc.: 0.817
# Epoch 19/20: Train loss: 0.237, Train acc.: 0.901, Val. loss: 0.434, Val. acc.: 0.817
# 	Batch 7/28: 	Train loss: 0.213, 	Train acc.: 0.910, 	Val. loss: 0.474, 	Val. acc.: 0.810
# 	Batch 14/28: 	Train loss: 0.240, 	Train acc.: 0.895, 	Val. loss: 0.446, 	Val. acc.: 0.814
# 	Batch 21/28: 	Train loss: 0.208, 	Train acc.: 0.911, 	Val. loss: 0.669, 	Val. acc.: 0.762
# 	Batch 28/28: 	Train loss: 0.211, 	Train acc.: 0.921, 	Val. loss: 0.821, 	Val. acc.: 0.738
# Epoch 20/20: Train loss: 0.218, Train acc.: 0.909, Val. loss: 0.821, Val. acc.: 0.738

# %% [markdown]
# **(1 point)**
#
# Create two plots. In one of them, plot the loss in the training and the validation datasets. In the other one, plot the accuracy in the training and validation datasets.

# %%
# YOUR CODE HERE

visual(train_losses_im, val_losses_im, 'Loss')
visual(train_accs_im, val_accs_im, 'Accuracy')

# %% [markdown]
# **(1 point)**
#
# How does the model perform, compared to the first CNN model? Create one plot with the training accuracy and another with the validation accuracy of the two models.

# %%
# YOUR CODE HERE
sns.set_context("talk")
sns.set_palette("husl")

def compare(init, impr, test_name, model_name1, model_name2):
    plt.figure(figsize=(12, 10))
    x1 = np.linspace(0, num_epochs, len(init))
    x2 = np.linspace(0, num_epochs, len(impr))
    plt.plot(x1, init, label=f'{test_name} for {model_name1}', linewidth=2, linestyle='-')
    plt.plot(x2, impr, label=f'{test_name} for {model_name2}', linewidth=2, linestyle='--')
    plt.legend(frameon=False)
    plt.title(f'{test_name} comparison')
    plt.xlabel('Epochs')
    plt.ylabel(test_name)
    sns.despine()
    plt.show()

compare(train_accs, train_accs_im, 'Training accuracy', 'initial model', 'improved model')
compare(val_accs, val_accs_im, 'Validation accuracy', 'initial model', 'improved model')

# %% [markdown]
# **(3 points)**
#
# Did your results improve? What problems did your improvements fix? Explain why, or why not.

# %% [markdown]
# **Your answer:**
# Yes, the performance improved because I added some general tricks:
# 1. ImprovedCnn has more convolutional layers and neurons compared to the FirstCnn, allowing it to learn more complex features from the images.
# 2. ImprovedCnn uses batch normalization, lead to faster convergence.
# 3. ImprovedCnn uses dropout to prevent overfitting, lead to a more generalized model.
# 4. ImprovedCnn model uses max pooling which can also add some level of translational invariance.
# 5.  ImprovedCnn uses an adjusted learning rate $1e-3$, lead to more stable training.

# %% [markdown]
# Save your model to disk.

# %%
# Assuming that you named your model "impr_model"
torch.save({'model_state_dict': model_im.state_dict(),
            'train_losses': train_losses_im,
            'train_accs': train_accs_im,
            'val_losses': val_losses_im,
            'val_accs': val_accs_im,
            }, "./improved_model.ckpt")

# %%
# YOUR CODE HERE
saved_first_model = ImprovedCnn(img_size=img_size) 
checkpoint = torch.load("improved_model.ckpt")
saved_first_model.load_state_dict(checkpoint['model_state_dict'])

# Example of re-using saved statistics:
print("Validation accuracies:", checkpoint['val_accs'])
# Out:
# Validation accuracies: [0.4904891304516544, 0.5310518567760786, 0.6745923906564713, 0.669525588552157, 0.7349694321552912, 0.7373188436031342, 0.6423233697811762, 0.7570482343435287, 0.7777117292086283, 0.7656816144784292, 0.715240036447843, 0.7304404427607855, 0.730865036447843, 0.7881850103537241, 0.7545572916666666, 0.794525588552157, 0.799677312374115, 0.7498018592596054, 0.8173686613639196, 0.7382529427607855]

# %% [markdown]
# ---
# ## 4. Transfer Learning

# %% [markdown]
# **From now, training on a CPU will likely not be feasible. If your computer has a GPU, try it out! Otherwise, now is the time to connect to your cloud instance**
#
# Now, instead of trying to come up with a good architecture for this task, we'll use the VGG16 architecture, but with the top layers removed (the fully connected layers + softmax). We'll substitute them with our own top network, designed for dog/cat classification.
# This top network is often called the "head" in transfer learning.
#
# However, this model has a very high capacity, and will probably suffer a lot from overfitting if we try to train it from scratch, using only our small subset of data. Instead, we'll start the optimization with the weights obtained after training VGG16 on the ImageNet dataset.
#
# Start by loading the *pretrained* VGG16 model, from the [torchvision.models](https://pytorch.org/vision/stable/models.html?highlight=vgg#torchvision.models.vgg16).

# %%
from torchvision import models
vgg_model = models.vgg16(weights=models.VGG16_Weights)
print(vgg_model.classifier)
# Out:
# /Users/bleuoutremer/anaconda3/envs/dml/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %% [markdown]
# **(1 point)**
#
# Create a new model as a so-called head network to the base VGG model.
# VGG is a relatively deep network so think about what would be a reasonable model head for transfer learning.
#
# *Hint:*
# - You can access and modify the top layers of the VGG model with `vgg_model.classifier`, and the remaining layers with `vgg_model.features`.
# - You can get the number of output features of `vgg_model.features` with `vgg_model.classifier[0].in_features`

# %%
# YOUR CODE HERE
num_features = vgg_model.classifier[0].in_features
class SqueezeLayer(nn.Module):
    def forward(self, x):
        return x.squeeze()

new = nn.Sequential(
    nn.Linear(num_features, 4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096, 4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096, 1),
    nn.Sigmoid(),
    SqueezeLayer()
)

# %% [markdown]
# **(2 points)**
#
# Now add the new model on top of VGG.

# %%
# YOUR CODE HERE
vgg_model.classifier = new

# %% [markdown]
# ### 4.1 Using VGG features

# %% [markdown]
# **(1 point)**
#
# Now we're almost ready to train the new model. For transfer learning we want to freeze all but the top layers in your architecture (i.e. signal to the optimizer that the bottom layers should not be changed during optimization) by setting the attribute `requires_grad` for all parameters `vgg_model.features` to `False`.

# %%
# YOUR CODE HERE
for param in vgg_model.features.parameters():
    param.requires_grad = False

# %% [markdown]
# **(1 point)**
#
# Prepare dataloaders for transfer learning. Don't forget that the VGG network is specialised for images of a certain size.

# %%
# YOUR CODE HERE
img_size = 224
batch_size = 64
transform_vgg = Compose([Resize((img_size, img_size)), ToTensor()])
small_train = DogsCatsData(root=small_train_path, transform=transform_vgg)
small_val = DogsCatsData(root=small_val_path, transform=transform_vgg)

small_train_loader_vgg = DataLoader(small_train, batch_size=batch_size, shuffle=True)
small_val_loader_vgg = DataLoader(small_val, batch_size=batch_size, shuffle=False)

def test_dataloader_for_VGG(dataloader):
    img_height, img_width = next(iter(dataloader))[0].shape[2:4]
    assert img_height == 224, "Image height is not suitable for VGG."
    assert img_width == 224, "Image width is not suitable for VGG."
    print("Test passed!")

# Assuming you created train_dataloader and val_dataloader
test_dataloader_for_VGG(small_train_loader_vgg)
test_dataloader_for_VGG(small_val_loader_vgg)
# Out:
# Test passed!
# Test passed!

# %% [markdown]
# **(1 point)**
#
# Perform the transfer learning by training the top layers of your model.

# %%
# YOUR CODE HERE

print_every = 11
num_epochs = 20
lr = 1e-5
criterion = nn.BCELoss()
optimizer = optim.Adam(vgg_model.parameters(), lr=lr)
torch.cuda.empty_cache()
model_vgg, train_losses_vgg, train_accs_vgg, val_losses_vgg, val_accs_vgg = training_loop(
    model=vgg_model,
    optimizer=optimizer,
    loss_fn=criterion,
    train_loader=small_train_loader_vgg,  
    val_loader=small_val_loader_vgg,  
    num_epochs=num_epochs,
    print_every=print_every
)
# Out:
# Starting training
# 	Batch 11/55: 	Train loss: 0.619, 	Train acc.: 0.730, 	Val. loss: 0.500, 	Val. acc.: 0.958
# 	Batch 22/55: 	Train loss: 0.446, 	Train acc.: 0.938, 	Val. loss: 0.336, 	Val. acc.: 0.965
# 	Batch 33/55: 	Train loss: 0.323, 	Train acc.: 0.940, 	Val. loss: 0.222, 	Val. acc.: 0.964
# 	Batch 44/55: 	Train loss: 0.241, 	Train acc.: 0.932, 	Val. loss: 0.158, 	Val. acc.: 0.969
# 	Batch 55/55: 	Train loss: 0.170, 	Train acc.: 0.940, 	Val. loss: 0.126, 	Val. acc.: 0.969
# Epoch 1/20: Train loss: 0.360, Train acc.: 0.896, Val. loss: 0.126, Val. acc.: 0.969
# 	Batch 11/55: 	Train loss: 0.139, 	Train acc.: 0.963, 	Val. loss: 0.108, 	Val. acc.: 0.971
# 	Batch 22/55: 	Train loss: 0.107, 	Train acc.: 0.976, 	Val. loss: 0.099, 	Val. acc.: 0.971
# 	Batch 33/55: 	Train loss: 0.121, 	Train acc.: 0.963, 	Val. loss: 0.090, 	Val. acc.: 0.973
# 	Batch 44/55: 	Train loss: 0.118, 	Train acc.: 0.963, 	Val. loss: 0.083, 	Val. acc.: 0.974
# 	Batch 55/55: 	Train loss: 0.098, 	Train acc.: 0.968, 	Val. loss: 0.079, 	Val. acc.: 0.973
# Epoch 2/20: Train loss: 0.116, Train acc.: 0.967, Val. loss: 0.079, Val. acc.: 0.973
# 	Batch 11/55: 	Train loss: 0.078, 	Train acc.: 0.984, 	Val. loss: 0.080, 	Val. acc.: 0.973
# 	Batch 22/55: 	Train loss: 0.074, 	Train acc.: 0.983, 	Val. loss: 0.074, 	Val. acc.: 0.974
# 	Batch 33/55: 	Train loss: 0.069, 	Train acc.: 0.983, 	Val. loss: 0.071, 	Val. acc.: 0.975
# 	Batch 44/55: 	Train loss: 0.058, 	Train acc.: 0.982, 	Val. loss: 0.074, 	Val. acc.: 0.971
# 	Batch 55/55: 	Train loss: 0.064, 	Train acc.: 0.983, 	Val. loss: 0.069, 	Val. acc.: 0.974
# Epoch 3/20: Train loss: 0.069, Train acc.: 0.983, Val. loss: 0.069, Val. acc.: 0.974
# 	Batch 11/55: 	Train loss: 0.046, 	Train acc.: 0.994, 	Val. loss: 0.067, 	Val. acc.: 0.973
# 	Batch 22/55: 	Train loss: 0.055, 	Train acc.: 0.982, 	Val. loss: 0.064, 	Val. acc.: 0.973
# 	Batch 33/55: 	Train loss: 0.039, 	Train acc.: 0.996, 	Val. loss: 0.067, 	Val. acc.: 0.975
# 	Batch 44/55: 	Train loss: 0.044, 	Train acc.: 0.990, 	Val. loss: 0.063, 	Val. acc.: 0.975
# 	Batch 55/55: 	Train loss: 0.044, 	Train acc.: 0.989, 	Val. loss: 0.064, 	Val. acc.: 0.974
# Epoch 4/20: Train loss: 0.046, Train acc.: 0.990, Val. loss: 0.064, Val. acc.: 0.974
# 	Batch 11/55: 	Train loss: 0.036, 	Train acc.: 0.993, 	Val. loss: 0.062, 	Val. acc.: 0.975
# 	Batch 22/55: 	Train loss: 0.028, 	Train acc.: 0.996, 	Val. loss: 0.065, 	Val. acc.: 0.972
# 	Batch 33/55: 	Train loss: 0.023, 	Train acc.: 1.000, 	Val. loss: 0.060, 	Val. acc.: 0.975
# 	Batch 44/55: 	Train loss: 0.025, 	Train acc.: 0.997, 	Val. loss: 0.061, 	Val. acc.: 0.975
# 	Batch 55/55: 	Train loss: 0.023, 	Train acc.: 1.000, 	Val. loss: 0.060, 	Val. acc.: 0.976
# Epoch 5/20: Train loss: 0.027, Train acc.: 0.997, Val. loss: 0.060, Val. acc.: 0.976
# 	Batch 11/55: 	Train loss: 0.015, 	Train acc.: 1.000, 	Val. loss: 0.060, 	Val. acc.: 0.976
# 	Batch 22/55: 	Train loss: 0.019, 	Train acc.: 0.999, 	Val. loss: 0.063, 	Val. acc.: 0.974
# 	Batch 33/55: 	Train loss: 0.018, 	Train acc.: 0.999, 	Val. loss: 0.063, 	Val. acc.: 0.973
# 	Batch 44/55: 	Train loss: 0.018, 	Train acc.: 0.999, 	Val. loss: 0.060, 	Val. acc.: 0.973
# 	Batch 55/55: 	Train loss: 0.014, 	Train acc.: 1.000, 	Val. loss: 0.064, 	Val. acc.: 0.972
# Epoch 6/20: Train loss: 0.017, Train acc.: 0.999, Val. loss: 0.064, Val. acc.: 0.972
# 	Batch 11/55: 	Train loss: 0.014, 	Train acc.: 0.999, 	Val. loss: 0.061, 	Val. acc.: 0.972
# 	Batch 22/55: 	Train loss: 0.012, 	Train acc.: 0.999, 	Val. loss: 0.063, 	Val. acc.: 0.972
# 	Batch 33/55: 	Train loss: 0.010, 	Train acc.: 1.000, 	Val. loss: 0.061, 	Val. acc.: 0.972
# 	Batch 44/55: 	Train loss: 0.010, 	Train acc.: 1.000, 	Val. loss: 0.064, 	Val. acc.: 0.973
# 	Batch 55/55: 	Train loss: 0.008, 	Train acc.: 1.000, 	Val. loss: 0.062, 	Val. acc.: 0.972
# Epoch 7/20: Train loss: 0.011, Train acc.: 0.999, Val. loss: 0.062, Val. acc.: 0.972
# 	Batch 11/55: 	Train loss: 0.008, 	Train acc.: 1.000, 	Val. loss: 0.066, 	Val. acc.: 0.972
# 	Batch 22/55: 	Train loss: 0.007, 	Train acc.: 1.000, 	Val. loss: 0.062, 	Val. acc.: 0.974
# 	Batch 33/55: 	Train loss: 0.008, 	Train acc.: 1.000, 	Val. loss: 0.062, 	Val. acc.: 0.973
# 	Batch 44/55: 	Train loss: 0.006, 	Train acc.: 1.000, 	Val. loss: 0.063, 	Val. acc.: 0.972
# 	Batch 55/55: 	Train loss: 0.007, 	Train acc.: 1.000, 	Val. loss: 0.063, 	Val. acc.: 0.972
# Epoch 8/20: Train loss: 0.007, Train acc.: 1.000, Val. loss: 0.063, Val. acc.: 0.972
# 	Batch 11/55: 	Train loss: 0.005, 	Train acc.: 1.000, 	Val. loss: 0.064, 	Val. acc.: 0.972
# 	Batch 22/55: 	Train loss: 0.005, 	Train acc.: 1.000, 	Val. loss: 0.064, 	Val. acc.: 0.972
# 	Batch 33/55: 	Train loss: 0.005, 	Train acc.: 1.000, 	Val. loss: 0.063, 	Val. acc.: 0.973
# 	Batch 44/55: 	Train loss: 0.005, 	Train acc.: 1.000, 	Val. loss: 0.066, 	Val. acc.: 0.972
# 	Batch 55/55: 	Train loss: 0.006, 	Train acc.: 1.000, 	Val. loss: 0.063, 	Val. acc.: 0.974
# Epoch 9/20: Train loss: 0.005, Train acc.: 1.000, Val. loss: 0.063, Val. acc.: 0.974
# 	Batch 11/55: 	Train loss: 0.004, 	Train acc.: 1.000, 	Val. loss: 0.064, 	Val. acc.: 0.974
# 	Batch 22/55: 	Train loss: 0.004, 	Train acc.: 1.000, 	Val. loss: 0.066, 	Val. acc.: 0.972
# 	Batch 33/55: 	Train loss: 0.004, 	Train acc.: 1.000, 	Val. loss: 0.064, 	Val. acc.: 0.974
# 	Batch 44/55: 	Train loss: 0.004, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.972
# 	Batch 55/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.972
# Epoch 10/20: Train loss: 0.004, Train acc.: 1.000, Val. loss: 0.072, Val. acc.: 0.972
# 	Batch 11/55: 	Train loss: 0.004, 	Train acc.: 1.000, 	Val. loss: 0.065, 	Val. acc.: 0.973
# 	Batch 22/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.065, 	Val. acc.: 0.973
# 	Batch 33/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.972
# 	Batch 44/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.972
# 	Batch 55/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.972
# Epoch 11/20: Train loss: 0.003, Train acc.: 1.000, Val. loss: 0.068, Val. acc.: 0.972
# 	Batch 11/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.066, 	Val. acc.: 0.974
# 	Batch 22/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.972
# 	Batch 33/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.972
# 	Batch 44/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.972
# 	Batch 55/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.972
# Epoch 12/20: Train loss: 0.002, Train acc.: 1.000, Val. loss: 0.070, Val. acc.: 0.972
# 	Batch 11/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.972
# 	Batch 22/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.972
# 	Batch 33/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.974
# 	Batch 44/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.973
# 	Batch 55/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.973
# Epoch 13/20: Train loss: 0.002, Train acc.: 1.000, Val. loss: 0.069, Val. acc.: 0.973
# 	Batch 11/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.973
# 	Batch 22/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.971
# 	Batch 33/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.972
# 	Batch 44/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.972
# 	Batch 55/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.975
# Epoch 14/20: Train loss: 0.002, Train acc.: 1.000, Val. loss: 0.069, Val. acc.: 0.975
# 	Batch 11/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.973
# 	Batch 22/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.973
# 	Batch 33/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.974
# 	Batch 44/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.974
# 	Batch 55/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.974
# Epoch 15/20: Train loss: 0.001, Train acc.: 1.000, Val. loss: 0.072, Val. acc.: 0.974
# 	Batch 11/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.972
# 	Batch 22/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.974
# 	Batch 33/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.974
# 	Batch 44/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.974
# 	Batch 55/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.974
# Epoch 16/20: Train loss: 0.001, Train acc.: 1.000, Val. loss: 0.075, Val. acc.: 0.974
# 	Batch 11/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.973
# 	Batch 22/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.972
# 	Batch 33/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.973
# 	Batch 44/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.972
# 	Batch 55/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.974
# Epoch 17/20: Train loss: 0.001, Train acc.: 1.000, Val. loss: 0.073, Val. acc.: 0.974
# 	Batch 11/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.974
# 	Batch 22/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.974
# 	Batch 33/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.974
# 	Batch 44/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.974
# 	Batch 55/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.974
# Epoch 18/20: Train loss: 0.001, Train acc.: 1.000, Val. loss: 0.074, Val. acc.: 0.974
# 	Batch 11/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.974
# 	Batch 22/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.076, 	Val. acc.: 0.973
# 	Batch 33/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.974
# 	Batch 44/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.076, 	Val. acc.: 0.974
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.076, 	Val. acc.: 0.974
# Epoch 19/20: Train loss: 0.001, Train acc.: 1.000, Val. loss: 0.076, Val. acc.: 0.974
# 	Batch 11/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.076, 	Val. acc.: 0.974
# 	Batch 22/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.076, 	Val. acc.: 0.974
# 	Batch 33/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.077, 	Val. acc.: 0.974
# 	Batch 44/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.078, 	Val. acc.: 0.974
# 	Batch 55/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.077, 	Val. acc.: 0.974
# Epoch 20/20: Train loss: 0.001, Train acc.: 1.000, Val. loss: 0.077, Val. acc.: 0.974

# %% [markdown]
# **(1 point)**
#
# Create two plots. In one of them, plot the loss in the training and the validation datasets. In the other one, plot the accuracy in the training and validation datasets.

# %%
# YOUR CODE HERE
visual(train_losses_vgg, val_losses_vgg, 'Loss')
visual(train_accs_vgg, val_accs_vgg, 'Accuracy')

# %% [markdown]
# **(2 points)**
#
# How does the model perform, compared to the model obtained in step 3? Create one plot with the training accuracy and another with the validation accuracy of the two scenarios.

# %%
# YOUR CODE HERE
compare(train_accs_im, train_accs_vgg, 'Training accuracy', 'improved model', 'transfer model')
compare(val_accs_im, val_accs_vgg, 'Validation accuracy', 'improved model', 'transfer model')

# %% [markdown]
# **(3 points)**
#
# Compare these results. Which approach worked best, starting from scratch or doing transfer learning? Reflect on whether your comparison is fair or not:

# %% [markdown]
# **Your answer:**
#
# Obviously both of train accuracy and validation accuracy of **model_vgg** is much higher than **ImprovedCnn**. The comparison is somehow unfair, because VGG16 has been trained on the ImageNet dataset and has learned a wide variety of features, also with a deeper architecture. However, the **ImprovedCnn** model started with random weights and only had access to the smaller Dogs vs Cats dataset.

# %% [markdown]
# **(2 points)**
#
# What are the main differences between the ImageNet dataset and the Dogs vs Cats dataset we used?

# %% [markdown]
# **Your answer:**
# 1.  ImageNet has more than  a million images with 1000 classes, while the Dogs vs Cats dataset is much smaller.
# 2.  The Dogs vs Cats dataset images has low resolutions.
# 3.  ImageNet contains a wide variety of classes, while he Dogs vs Cats dataset only has two classes.

# %% [markdown]
# **(2 points)**
#
# Even though there are considerable differences between these datasets, why is it that transfer learning is still a good idea?

# %% [markdown]
# **Your answer:**
# 1. Basic image features, for example, edges, remain consistent across various datasets. These also work for distinguish dogs and cats.
# 2. Using transfer learning, we can utilize a pre-trained model, which results in quicker optimization.
# 3. Transfer learning can act as regularization.

# %% [markdown]
# **(1 point)**
#
# In which scenario would transfer learning be unsuitable?

# %% [markdown]
# **Your answer:**
#
# 1. If we concern about computational efficiency and memory size, we won't use a large pre-trained model.
# 2. If the new dataset has completely different characteristics than the pre-trained datasetk, transfer learning won't work.

# %% [markdown]
# Save the model to a file.

# %%
# YOUR CODE HERE
torch.save({'model_state_dict': model_vgg.state_dict(),
            'train_losses': train_losses_vgg,
            'train_accs': train_accs_vgg,
            'val_losses': val_losses_vgg,
            'val_accs': val_accs_vgg,
            }, "./model_vgg.ckpt")
saved_model = model_vgg
checkpoint = torch.load("model_vgg.ckpt")
saved_model.load_state_dict(checkpoint['model_state_dict'])

print("Validation accuracies:", checkpoint['val_accs'])
# Out:
# Validation accuracies: [0.96875, 0.9733072916666666, 0.9739583333333334, 0.9737723221381506, 0.9759114583333334, 0.9724702388048172, 0.9724702388048172, 0.9724702388048172, 0.9737723221381506, 0.9722842276096344, 0.9724702388048172, 0.9716331859429678, 0.9731212804714838, 0.9750744054714838, 0.9737723221381506, 0.9737723221381506, 0.9744233638048172, 0.9744233638048172, 0.9744233638048172, 0.9737723221381506]

# %% [markdown]
# ### 4.2 Fine-tuning

# %% [markdown]
# Now that we have a better starting point for the top layers, we can train the entire network. Unfreeze the bottom layers by resetting the `requires_grad` attribute to `True`.

# %%
# YOUR CODE HERE
for param in vgg_model.features.parameters():
    param.requires_grad = True

# %% [markdown]
# **(1 point)**
#
# Fine tune the model by training all the layers.

# %%
# YOUR CODE HERE
print_every = 11
num_epochs = 20
lr = 1e-5
criterion = nn.BCELoss()
optimizer = optim.Adam(vgg_model.parameters(), lr=lr)
torch.cuda.empty_cache()
model_vgg_all, train_losses_vgg_all, train_accs_vgg_all, val_losses_vgg_all, val_accs_vgg_all = training_loop(
    model=vgg_model,
    optimizer=optimizer,
    loss_fn=criterion,
    train_loader=small_train_loader_vgg,  
    val_loader=small_val_loader_vgg,  
    num_epochs=num_epochs,
    print_every=print_every
)
# Out:
# Starting training
# 	Batch 11/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.105, 	Val. acc.: 0.969
# 	Batch 22/55: 	Train loss: 0.004, 	Train acc.: 0.999, 	Val. loss: 0.080, 	Val. acc.: 0.976
# 	Batch 33/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.138, 	Val. acc.: 0.964
# 	Batch 44/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.078, 	Val. acc.: 0.977
# 	Batch 55/55: 	Train loss: 0.003, 	Train acc.: 0.999, 	Val. loss: 0.069, 	Val. acc.: 0.981
# Epoch 1/20: Train loss: 0.002, Train acc.: 0.999, Val. loss: 0.069, Val. acc.: 0.981
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.064, 	Val. acc.: 0.981
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.062, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.977
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.064, 	Val. acc.: 0.981
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.061, 	Val. acc.: 0.980
# Epoch 2/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.061, Val. acc.: 0.980
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.062, 	Val. acc.: 0.981
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.065, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.066, 	Val. acc.: 0.981
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.064, 	Val. acc.: 0.981
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.063, 	Val. acc.: 0.980
# Epoch 3/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.063, Val. acc.: 0.980
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.063, 	Val. acc.: 0.980
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.063, 	Val. acc.: 0.980
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.064, 	Val. acc.: 0.981
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.981
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.981
# Epoch 4/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.068, Val. acc.: 0.981
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.066, 	Val. acc.: 0.981
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.066, 	Val. acc.: 0.981
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.066, 	Val. acc.: 0.981
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.067, 	Val. acc.: 0.981
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.981
# Epoch 5/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.068, Val. acc.: 0.981
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.982
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.981
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.981
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.981
# Epoch 6/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.068, Val. acc.: 0.981
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.981
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.981
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.981
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.981
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.981
# Epoch 7/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.069, Val. acc.: 0.981
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.981
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.981
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.982
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# Epoch 8/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.071, Val. acc.: 0.982
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.981
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.981
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# Epoch 9/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.071, Val. acc.: 0.982
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# Epoch 10/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.071, Val. acc.: 0.982
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.982
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.982
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.981
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.981
# Epoch 11/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.071, Val. acc.: 0.981
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.981
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.981
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.981
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.981
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.981
# Epoch 12/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.072, Val. acc.: 0.981
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.981
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.981
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.981
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.981
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.982
# Epoch 13/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.073, Val. acc.: 0.982
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.981
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.981
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.982
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.982
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.072, 	Val. acc.: 0.982
# Epoch 14/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.072, Val. acc.: 0.982
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.982
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.981
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.981
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.981
# Epoch 15/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.074, Val. acc.: 0.981
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.981
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# Epoch 16/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.074, Val. acc.: 0.982
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.982
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# Epoch 17/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.074, Val. acc.: 0.982
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.074, 	Val. acc.: 0.982
# Epoch 18/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.074, Val. acc.: 0.982
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.982
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.076, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.077, 	Val. acc.: 0.983
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.076, 	Val. acc.: 0.983
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.076, 	Val. acc.: 0.983
# Epoch 19/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.076, Val. acc.: 0.983
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.982
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.982
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.982
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.982
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.075, 	Val. acc.: 0.982
# Epoch 20/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.075, Val. acc.: 0.982

# %% [markdown]
# **(1 point)**
#
# How does the model perform, compared to the model trained with frozen layers? Create one plot with the training accuracy and another with the validation accuracy of the two scenarios.

# %%
# YOUR CODE HERE
compare(train_accs_vgg, train_accs_vgg_all, 'Training accuracy', 'frozen layers model', 'complete model')
compare(val_accs_vgg, val_accs_vgg_all, 'Validation accuracy', 'frozen layers model', 'complete model')

# %% [markdown]
# **(2 points)**
#
# Why is it a good idea to use a very small learning rate when doing fine tuning?

# %% [markdown]
# **Your answer:**
# 1. Our goal is to make slight modifications because the model already starts at a good point.
# 2. Larger weight updates may lead to the model overfitting.
# 3. To preserve the learned features from pre-trained model.

# %% [markdown]
# Save the model to file.

# %%
# YOUR CODE HERE
torch.save({'model_state_dict': model_vgg_all.state_dict(),
            'train_losses': train_losses_vgg_all,
            'train_accs': train_accs_vgg_all,
            'val_losses': val_losses_vgg_all,
            'val_accs': val_accs_vgg_all,
            }, "./model_vgg_all.ckpt")
saved_model = model_vgg_all
checkpoint = torch.load("model_vgg_all.ckpt")
saved_model.load_state_dict(checkpoint['model_state_dict'])

print("Validation accuracies:", checkpoint['val_accs'])
# Out:
# Validation accuracies: [0.9809337804714838, 0.9802827388048172, 0.9802827388048172, 0.9809337804714838, 0.9809337804714838, 0.9809337804714838, 0.9809337804714838, 0.9815848221381506, 0.9815848221381506, 0.9815848221381506, 0.9809337804714838, 0.9809337804714838, 0.9815848221381506, 0.982421875, 0.9809337804714838, 0.982421875, 0.982421875, 0.982421875, 0.9830729166666666, 0.982421875]

# %% [markdown]
# ### 4.3 Improving the top model (optional)

# %% [markdown]
# Improve the architecture for the layers you add on top of VGG16. Try different ideas! When you're happy with one architecture, copy it in the cell below and train it here.

# %%
# YOUR CODE HERE
num_features = vgg_model.classifier[0].in_features
class SqueezeLayer(nn.Module):
    def forward(self, x):
        return x.squeeze()

optional = nn.Sequential(
    nn.Linear(num_features, 4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096, 4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096, 4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096, 1),
    nn.Sigmoid(),
    SqueezeLayer()
)
vgg_model.classifier = optional

for param in vgg_model.features.parameters():
    param.requires_grad = True

#initialization
print_every = 11
num_epochs = 20
lr = 1e-5
criterion = nn.BCELoss()
optimizer = optim.Adam(vgg_model.parameters(), lr=lr)
torch.cuda.empty_cache()

#train top model
model_vgg_top, train_losses_vgg_top, train_accs_vgg_top, val_losses_vgg_top, val_accs_vgg_top = training_loop(
    model=vgg_model,
    optimizer=optimizer,
    loss_fn=criterion,
    train_loader=small_train_loader_vgg,  
    val_loader=small_val_loader_vgg,  
    num_epochs=num_epochs,
    print_every=print_every
)
# Out:
# Starting training
# 	Batch 11/55: 	Train loss: 0.658, 	Train acc.: 0.642, 	Val. loss: 0.572, 	Val. acc.: 0.864
# 	Batch 22/55: 	Train loss: 0.506, 	Train acc.: 0.855, 	Val. loss: 0.262, 	Val. acc.: 0.981
# 	Batch 33/55: 	Train loss: 0.190, 	Train acc.: 0.966, 	Val. loss: 0.070, 	Val. acc.: 0.975
# 	Batch 44/55: 	Train loss: 0.090, 	Train acc.: 0.969, 	Val. loss: 0.052, 	Val. acc.: 0.976
# 	Batch 55/55: 	Train loss: 0.091, 	Train acc.: 0.973, 	Val. loss: 0.049, 	Val. acc.: 0.979
# Epoch 1/20: Train loss: 0.307, Train acc.: 0.881, Val. loss: 0.049, Val. acc.: 0.979
# 	Batch 11/55: 	Train loss: 0.044, 	Train acc.: 0.989, 	Val. loss: 0.044, 	Val. acc.: 0.984
# 	Batch 22/55: 	Train loss: 0.044, 	Train acc.: 0.984, 	Val. loss: 0.034, 	Val. acc.: 0.987
# 	Batch 33/55: 	Train loss: 0.061, 	Train acc.: 0.982, 	Val. loss: 0.036, 	Val. acc.: 0.986
# 	Batch 44/55: 	Train loss: 0.036, 	Train acc.: 0.990, 	Val. loss: 0.036, 	Val. acc.: 0.988
# 	Batch 55/55: 	Train loss: 0.043, 	Train acc.: 0.990, 	Val. loss: 0.038, 	Val. acc.: 0.990
# Epoch 2/20: Train loss: 0.046, Train acc.: 0.987, Val. loss: 0.038, Val. acc.: 0.990
# 	Batch 11/55: 	Train loss: 0.021, 	Train acc.: 0.994, 	Val. loss: 0.035, 	Val. acc.: 0.987
# 	Batch 22/55: 	Train loss: 0.025, 	Train acc.: 0.994, 	Val. loss: 0.032, 	Val. acc.: 0.989
# 	Batch 33/55: 	Train loss: 0.017, 	Train acc.: 0.993, 	Val. loss: 0.030, 	Val. acc.: 0.990
# 	Batch 44/55: 	Train loss: 0.017, 	Train acc.: 0.996, 	Val. loss: 0.031, 	Val. acc.: 0.990
# 	Batch 55/55: 	Train loss: 0.026, 	Train acc.: 0.990, 	Val. loss: 0.033, 	Val. acc.: 0.989
# Epoch 3/20: Train loss: 0.021, Train acc.: 0.993, Val. loss: 0.033, Val. acc.: 0.989
# 	Batch 11/55: 	Train loss: 0.010, 	Train acc.: 0.999, 	Val. loss: 0.028, 	Val. acc.: 0.992
# 	Batch 22/55: 	Train loss: 0.007, 	Train acc.: 1.000, 	Val. loss: 0.028, 	Val. acc.: 0.991
# 	Batch 33/55: 	Train loss: 0.006, 	Train acc.: 1.000, 	Val. loss: 0.031, 	Val. acc.: 0.992
# 	Batch 44/55: 	Train loss: 0.007, 	Train acc.: 1.000, 	Val. loss: 0.033, 	Val. acc.: 0.988
# 	Batch 55/55: 	Train loss: 0.007, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.990
# Epoch 4/20: Train loss: 0.007, Train acc.: 1.000, Val. loss: 0.038, Val. acc.: 0.990
# 	Batch 11/55: 	Train loss: 0.004, 	Train acc.: 1.000, 	Val. loss: 0.031, 	Val. acc.: 0.991
# 	Batch 22/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.029, 	Val. acc.: 0.990
# 	Batch 33/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.032, 	Val. acc.: 0.990
# 	Batch 44/55: 	Train loss: 0.004, 	Train acc.: 1.000, 	Val. loss: 0.034, 	Val. acc.: 0.989
# 	Batch 55/55: 	Train loss: 0.003, 	Train acc.: 0.999, 	Val. loss: 0.039, 	Val. acc.: 0.989
# Epoch 5/20: Train loss: 0.003, Train acc.: 1.000, Val. loss: 0.039, Val. acc.: 0.989
# 	Batch 11/55: 	Train loss: 0.003, 	Train acc.: 0.999, 	Val. loss: 0.038, 	Val. acc.: 0.988
# 	Batch 22/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.988
# 	Batch 33/55: 	Train loss: 0.002, 	Train acc.: 0.999, 	Val. loss: 0.037, 	Val. acc.: 0.989
# 	Batch 44/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.036, 	Val. acc.: 0.987
# 	Batch 55/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.035, 	Val. acc.: 0.986
# Epoch 6/20: Train loss: 0.003, Train acc.: 0.999, Val. loss: 0.035, Val. acc.: 0.986
# 	Batch 11/55: 	Train loss: 0.002, 	Train acc.: 0.999, 	Val. loss: 0.052, 	Val. acc.: 0.985
# 	Batch 22/55: 	Train loss: 0.004, 	Train acc.: 0.999, 	Val. loss: 0.043, 	Val. acc.: 0.987
# 	Batch 33/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.986
# 	Batch 44/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.987
# 	Batch 55/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.986
# Epoch 7/20: Train loss: 0.002, Train acc.: 0.999, Val. loss: 0.048, Val. acc.: 0.986
# 	Batch 11/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.987
# 	Batch 22/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.050, 	Val. acc.: 0.987
# 	Batch 33/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.987
# 	Batch 44/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.987
# 	Batch 55/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.987
# Epoch 8/20: Train loss: 0.001, Train acc.: 1.000, Val. loss: 0.046, Val. acc.: 0.987
# 	Batch 11/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.052, 	Val. acc.: 0.986
# 	Batch 22/55: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.060, 	Val. acc.: 0.985
# 	Batch 33/55: 	Train loss: 0.004, 	Train acc.: 0.999, 	Val. loss: 0.082, 	Val. acc.: 0.982
# 	Batch 44/55: 	Train loss: 0.009, 	Train acc.: 0.997, 	Val. loss: 0.066, 	Val. acc.: 0.982
# 	Batch 55/55: 	Train loss: 0.004, 	Train acc.: 0.999, 	Val. loss: 0.056, 	Val. acc.: 0.983
# Epoch 9/20: Train loss: 0.004, Train acc.: 0.999, Val. loss: 0.056, Val. acc.: 0.983
# 	Batch 11/55: 	Train loss: 0.002, 	Train acc.: 0.999, 	Val. loss: 0.039, 	Val. acc.: 0.988
# 	Batch 22/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.989
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.049, 	Val. acc.: 0.987
# 	Batch 44/55: 	Train loss: 0.002, 	Train acc.: 0.999, 	Val. loss: 0.057, 	Val. acc.: 0.983
# 	Batch 55/55: 	Train loss: 0.003, 	Train acc.: 0.999, 	Val. loss: 0.038, 	Val. acc.: 0.988
# Epoch 10/20: Train loss: 0.002, Train acc.: 0.999, Val. loss: 0.038, Val. acc.: 0.988
# 	Batch 11/55: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.035, 	Val. acc.: 0.988
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.990
# 	Batch 33/55: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.990
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.037, 	Val. acc.: 0.988
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.990
# Epoch 11/20: Train loss: 0.001, Train acc.: 1.000, Val. loss: 0.038, Val. acc.: 0.990
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.990
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.990
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.990
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.990
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.989
# Epoch 12/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.040, Val. acc.: 0.989
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.990
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.990
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.989
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.987
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.987
# Epoch 13/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.043, Val. acc.: 0.987
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.987
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.987
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.987
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.988
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.987
# Epoch 14/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.043, Val. acc.: 0.987
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.987
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.987
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.045, 	Val. acc.: 0.987
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.045, 	Val. acc.: 0.987
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.987
# Epoch 15/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.044, Val. acc.: 0.987
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.987
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.045, 	Val. acc.: 0.987
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.047, 	Val. acc.: 0.987
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.047, 	Val. acc.: 0.987
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.987
# Epoch 16/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.046, Val. acc.: 0.987
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.987
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.987
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.987
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.063, 	Val. acc.: 0.987
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.050, 	Val. acc.: 0.989
# Epoch 17/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.050, Val. acc.: 0.989
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.990
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.990
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.989
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.047, 	Val. acc.: 0.990
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.989
# Epoch 18/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.048, Val. acc.: 0.989
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.989
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.988
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.049, 	Val. acc.: 0.988
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.989
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.988
# Epoch 19/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.048, Val. acc.: 0.988
# 	Batch 11/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.988
# 	Batch 22/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.049, 	Val. acc.: 0.988
# 	Batch 33/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.049, 	Val. acc.: 0.988
# 	Batch 44/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.988
# 	Batch 55/55: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.988
# Epoch 20/20: Train loss: 0.000, Train acc.: 1.000, Val. loss: 0.048, Val. acc.: 0.988

# %% [markdown]
# **(1 point)**
#
# How does the model perform, compared to the model trained in step 4.2? Create one plot with the training accuracy and another with the validation accuracy of the two scenarios.

# %%
# YOUR CODE HERE
compare(train_accs_vgg_all, train_accs_vgg_top, 'Training accuracy', 'complete model', 'improved top model')
compare(val_accs_vgg_all, val_accs_vgg_top, 'Validation accuracy', 'complete model', 'improved top model')

# %% [markdown]
# Save the model to a file.

# %%
# YOUR CODE HERE
torch.save({'model_state_dict': model_vgg_top.state_dict(),
            'train_losses': train_losses_vgg_top,
            'train_accs': train_accs_vgg_top,
            'val_losses': val_losses_vgg_top,
            'val_accs': val_accs_vgg_top,
            }, "./model_vgg_top.ckpt")
saved_model = model_vgg_top
checkpoint = torch.load("model_vgg_top.ckpt")
saved_model.load_state_dict(checkpoint['model_state_dict'])

print("Validation accuracies:", checkpoint['val_accs'])
# Out:
# Validation accuracies: [0.9789806554714838, 0.990234375, 0.9893973221381506, 0.9895833333333334, 0.9889322916666666, 0.9861421138048172, 0.986328125, 0.9867931554714838, 0.982700894276301, 0.98828125, 0.9895833333333334, 0.9889322916666666, 0.9874441971381506, 0.9874441971381506, 0.9867931554714838, 0.9874441971381506, 0.9887462804714838, 0.9887462804714838, 0.9880952388048172, 0.9880952388048172]

# %% [markdown]
# ## 5. Final training

# %% [markdown]
# Now we'll train the model that achieved the best performance so far using the entire dataset.
#
# **Note**: start the optimization with the weights you obtained training in the smaller subset, i.e. *not* from scratch.

# %% [markdown]
# First, create two new data loaders, one for training samples and one for validation samples. This time, they'll load data from the folders for the entire dataset.

# %%
# YOUR CODE HERE
train = DogsCatsData(root=train_path, transform=transform_vgg)
val = DogsCatsData(root=val_path, transform=transform_vgg)
train_loader = DataLoader(train, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(val, batch_size=batch_size, shuffle=False)

# %% [markdown]
# **(1 point)**
#
# Train your model using the full data. This optimization might take a long time.

# %%
# YOUR CODE HERE
print_every = 11
num_epochs = 20
lr = 1e-5
criterion = nn.BCELoss()
optimizer = optim.Adam(vgg_model.parameters(), lr=lr)
torch.cuda.empty_cache()
model_vgg_final, train_losses_vgg_final, train_accs_vgg_final, val_losses_vgg_final, val_accs_vgg_final = training_loop(
    model=vgg_model,
    optimizer=optimizer,
    loss_fn=criterion,
    train_loader=train_loader,  
    val_loader=valid_loader,  
    num_epochs=num_epochs,
    print_every=print_every
)
# Out:
# Starting training
# 	Batch 11/313: 	Train loss: 0.078, 	Train acc.: 0.976, 	Val. loss: 0.092, 	Val. acc.: 0.985
# 	Batch 22/313: 	Train loss: 0.050, 	Train acc.: 0.986, 	Val. loss: 0.078, 	Val. acc.: 0.984
# 	Batch 33/313: 	Train loss: 0.166, 	Train acc.: 0.989, 	Val. loss: 0.065, 	Val. acc.: 0.985
# 	Batch 44/313: 	Train loss: 0.024, 	Train acc.: 0.987, 	Val. loss: 0.056, 	Val. acc.: 0.985
# 	Batch 55/313: 	Train loss: 0.030, 	Train acc.: 0.987, 	Val. loss: 0.050, 	Val. acc.: 0.986
# 	Batch 66/313: 	Train loss: 0.060, 	Train acc.: 0.983, 	Val. loss: 0.059, 	Val. acc.: 0.981
# 	Batch 77/313: 	Train loss: 0.037, 	Train acc.: 0.986, 	Val. loss: 0.039, 	Val. acc.: 0.986
# 	Batch 88/313: 	Train loss: 0.030, 	Train acc.: 0.990, 	Val. loss: 0.036, 	Val. acc.: 0.986
# 	Batch 99/313: 	Train loss: 0.060, 	Train acc.: 0.983, 	Val. loss: 0.038, 	Val. acc.: 0.987
# 	Batch 110/313: 	Train loss: 0.058, 	Train acc.: 0.983, 	Val. loss: 0.037, 	Val. acc.: 0.987
# 	Batch 121/313: 	Train loss: 0.033, 	Train acc.: 0.991, 	Val. loss: 0.032, 	Val. acc.: 0.988
# 	Batch 132/313: 	Train loss: 0.029, 	Train acc.: 0.993, 	Val. loss: 0.030, 	Val. acc.: 0.987
# 	Batch 143/313: 	Train loss: 0.042, 	Train acc.: 0.982, 	Val. loss: 0.029, 	Val. acc.: 0.988
# 	Batch 154/313: 	Train loss: 0.029, 	Train acc.: 0.991, 	Val. loss: 0.029, 	Val. acc.: 0.988
# 	Batch 165/313: 	Train loss: 0.040, 	Train acc.: 0.984, 	Val. loss: 0.029, 	Val. acc.: 0.988
# 	Batch 176/313: 	Train loss: 0.036, 	Train acc.: 0.987, 	Val. loss: 0.030, 	Val. acc.: 0.988
# 	Batch 187/313: 	Train loss: 0.021, 	Train acc.: 0.993, 	Val. loss: 0.034, 	Val. acc.: 0.987
# 	Batch 198/313: 	Train loss: 0.033, 	Train acc.: 0.989, 	Val. loss: 0.029, 	Val. acc.: 0.988
# 	Batch 209/313: 	Train loss: 0.175, 	Train acc.: 0.986, 	Val. loss: 0.039, 	Val. acc.: 0.986
# 	Batch 220/313: 	Train loss: 0.027, 	Train acc.: 0.990, 	Val. loss: 0.030, 	Val. acc.: 0.989
# 	Batch 231/313: 	Train loss: 0.026, 	Train acc.: 0.989, 	Val. loss: 0.029, 	Val. acc.: 0.989
# 	Batch 242/313: 	Train loss: 0.036, 	Train acc.: 0.987, 	Val. loss: 0.028, 	Val. acc.: 0.990
# 	Batch 253/313: 	Train loss: 0.016, 	Train acc.: 0.996, 	Val. loss: 0.029, 	Val. acc.: 0.990
# 	Batch 264/313: 	Train loss: 0.024, 	Train acc.: 0.993, 	Val. loss: 0.031, 	Val. acc.: 0.988
# 	Batch 275/313: 	Train loss: 0.037, 	Train acc.: 0.984, 	Val. loss: 0.028, 	Val. acc.: 0.989
# 	Batch 286/313: 	Train loss: 0.021, 	Train acc.: 0.990, 	Val. loss: 0.031, 	Val. acc.: 0.988
# 	Batch 297/313: 	Train loss: 0.029, 	Train acc.: 0.994, 	Val. loss: 0.031, 	Val. acc.: 0.988
# 	Batch 308/313: 	Train loss: 0.170, 	Train acc.: 0.990, 	Val. loss: 0.053, 	Val. acc.: 0.981
# Epoch 1/20: Train loss: 0.050, Train acc.: 0.988, Val. loss: 0.038, Val. acc.: 0.987
# 	Batch 11/313: 	Train loss: 0.020, 	Train acc.: 0.990, 	Val. loss: 0.041, 	Val. acc.: 0.986
# 	Batch 22/313: 	Train loss: 0.014, 	Train acc.: 0.994, 	Val. loss: 0.046, 	Val. acc.: 0.985
# 	Batch 33/313: 	Train loss: 0.149, 	Train acc.: 0.997, 	Val. loss: 0.035, 	Val. acc.: 0.989
# 	Batch 44/313: 	Train loss: 0.010, 	Train acc.: 0.999, 	Val. loss: 0.037, 	Val. acc.: 0.987
# 	Batch 55/313: 	Train loss: 0.010, 	Train acc.: 0.996, 	Val. loss: 0.030, 	Val. acc.: 0.988
# 	Batch 66/313: 	Train loss: 0.013, 	Train acc.: 0.996, 	Val. loss: 0.033, 	Val. acc.: 0.988
# 	Batch 77/313: 	Train loss: 0.162, 	Train acc.: 0.991, 	Val. loss: 0.035, 	Val. acc.: 0.988
# 	Batch 88/313: 	Train loss: 0.022, 	Train acc.: 0.994, 	Val. loss: 0.034, 	Val. acc.: 0.988
# 	Batch 99/313: 	Train loss: 0.016, 	Train acc.: 0.993, 	Val. loss: 0.035, 	Val. acc.: 0.988
# 	Batch 110/313: 	Train loss: 0.020, 	Train acc.: 0.996, 	Val. loss: 0.046, 	Val. acc.: 0.986
# 	Batch 121/313: 	Train loss: 0.015, 	Train acc.: 0.994, 	Val. loss: 0.037, 	Val. acc.: 0.989
# 	Batch 132/313: 	Train loss: 0.025, 	Train acc.: 0.991, 	Val. loss: 0.036, 	Val. acc.: 0.987
# 	Batch 143/313: 	Train loss: 0.016, 	Train acc.: 0.993, 	Val. loss: 0.028, 	Val. acc.: 0.990
# 	Batch 154/313: 	Train loss: 0.029, 	Train acc.: 0.991, 	Val. loss: 0.026, 	Val. acc.: 0.989
# 	Batch 165/313: 	Train loss: 0.015, 	Train acc.: 0.993, 	Val. loss: 0.027, 	Val. acc.: 0.989
# 	Batch 176/313: 	Train loss: 0.009, 	Train acc.: 0.996, 	Val. loss: 0.028, 	Val. acc.: 0.989
# 	Batch 187/313: 	Train loss: 0.153, 	Train acc.: 0.994, 	Val. loss: 0.030, 	Val. acc.: 0.989
# 	Batch 198/313: 	Train loss: 0.008, 	Train acc.: 0.997, 	Val. loss: 0.030, 	Val. acc.: 0.989
# 	Batch 209/313: 	Train loss: 0.010, 	Train acc.: 0.996, 	Val. loss: 0.031, 	Val. acc.: 0.988
# 	Batch 220/313: 	Train loss: 0.009, 	Train acc.: 0.997, 	Val. loss: 0.036, 	Val. acc.: 0.989
# 	Batch 231/313: 	Train loss: 0.012, 	Train acc.: 0.993, 	Val. loss: 0.033, 	Val. acc.: 0.988
# 	Batch 242/313: 	Train loss: 0.006, 	Train acc.: 0.997, 	Val. loss: 0.031, 	Val. acc.: 0.990
# 	Batch 253/313: 	Train loss: 0.012, 	Train acc.: 0.999, 	Val. loss: 0.033, 	Val. acc.: 0.988
# 	Batch 264/313: 	Train loss: 0.011, 	Train acc.: 0.996, 	Val. loss: 0.039, 	Val. acc.: 0.987
# 	Batch 275/313: 	Train loss: 0.023, 	Train acc.: 0.990, 	Val. loss: 0.035, 	Val. acc.: 0.989
# 	Batch 286/313: 	Train loss: 0.006, 	Train acc.: 0.999, 	Val. loss: 0.034, 	Val. acc.: 0.987
# 	Batch 297/313: 	Train loss: 0.009, 	Train acc.: 0.999, 	Val. loss: 0.034, 	Val. acc.: 0.988
# 	Batch 308/313: 	Train loss: 0.010, 	Train acc.: 0.994, 	Val. loss: 0.033, 	Val. acc.: 0.987
# Epoch 2/20: Train loss: 0.029, Train acc.: 0.995, Val. loss: 0.033, Val. acc.: 0.987
# 	Batch 11/313: 	Train loss: 0.008, 	Train acc.: 0.999, 	Val. loss: 0.043, 	Val. acc.: 0.988
# 	Batch 22/313: 	Train loss: 0.144, 	Train acc.: 0.999, 	Val. loss: 0.035, 	Val. acc.: 0.988
# 	Batch 33/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.036, 	Val. acc.: 0.989
# 	Batch 44/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.036, 	Val. acc.: 0.989
# 	Batch 55/313: 	Train loss: 0.009, 	Train acc.: 0.999, 	Val. loss: 0.035, 	Val. acc.: 0.988
# 	Batch 66/313: 	Train loss: 0.010, 	Train acc.: 0.999, 	Val. loss: 0.037, 	Val. acc.: 0.989
# 	Batch 77/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.034, 	Val. acc.: 0.988
# 	Batch 88/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.034, 	Val. acc.: 0.988
# 	Batch 99/313: 	Train loss: 0.006, 	Train acc.: 0.999, 	Val. loss: 0.035, 	Val. acc.: 0.988
# 	Batch 110/313: 	Train loss: 0.012, 	Train acc.: 0.991, 	Val. loss: 0.038, 	Val. acc.: 0.990
# 	Batch 121/313: 	Train loss: 0.010, 	Train acc.: 0.997, 	Val. loss: 0.043, 	Val. acc.: 0.988
# 	Batch 132/313: 	Train loss: 0.008, 	Train acc.: 0.997, 	Val. loss: 0.047, 	Val. acc.: 0.988
# 	Batch 143/313: 	Train loss: 0.008, 	Train acc.: 0.999, 	Val. loss: 0.034, 	Val. acc.: 0.989
# 	Batch 154/313: 	Train loss: 0.005, 	Train acc.: 0.999, 	Val. loss: 0.035, 	Val. acc.: 0.989
# 	Batch 165/313: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.988
# 	Batch 176/313: 	Train loss: 0.011, 	Train acc.: 0.993, 	Val. loss: 0.038, 	Val. acc.: 0.989
# 	Batch 187/313: 	Train loss: 0.007, 	Train acc.: 0.997, 	Val. loss: 0.048, 	Val. acc.: 0.988
# 	Batch 198/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.036, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.988
# 	Batch 220/313: 	Train loss: 0.006, 	Train acc.: 0.997, 	Val. loss: 0.062, 	Val. acc.: 0.987
# 	Batch 231/313: 	Train loss: 0.015, 	Train acc.: 0.994, 	Val. loss: 0.095, 	Val. acc.: 0.978
# 	Batch 242/313: 	Train loss: 0.046, 	Train acc.: 0.984, 	Val. loss: 0.094, 	Val. acc.: 0.977
# 	Batch 253/313: 	Train loss: 0.168, 	Train acc.: 0.990, 	Val. loss: 0.052, 	Val. acc.: 0.983
# 	Batch 264/313: 	Train loss: 0.148, 	Train acc.: 0.997, 	Val. loss: 0.037, 	Val. acc.: 0.987
# 	Batch 275/313: 	Train loss: 0.005, 	Train acc.: 1.000, 	Val. loss: 0.031, 	Val. acc.: 0.988
# 	Batch 286/313: 	Train loss: 0.006, 	Train acc.: 0.999, 	Val. loss: 0.031, 	Val. acc.: 0.988
# 	Batch 297/313: 	Train loss: 0.006, 	Train acc.: 1.000, 	Val. loss: 0.033, 	Val. acc.: 0.988
# 	Batch 308/313: 	Train loss: 0.004, 	Train acc.: 1.000, 	Val. loss: 0.033, 	Val. acc.: 0.988
# Epoch 3/20: Train loss: 0.023, Train acc.: 0.997, Val. loss: 0.036, Val. acc.: 0.988
# 	Batch 11/313: 	Train loss: 0.005, 	Train acc.: 0.997, 	Val. loss: 0.033, 	Val. acc.: 0.988
# 	Batch 22/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.990
# 	Batch 33/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.036, 	Val. acc.: 0.988
# 	Batch 44/313: 	Train loss: 0.003, 	Train acc.: 0.999, 	Val. loss: 0.036, 	Val. acc.: 0.989
# 	Batch 55/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.037, 	Val. acc.: 0.989
# 	Batch 66/313: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.037, 	Val. acc.: 0.990
# 	Batch 77/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.037, 	Val. acc.: 0.990
# 	Batch 88/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.045, 	Val. acc.: 0.989
# 	Batch 99/313: 	Train loss: 0.002, 	Train acc.: 0.999, 	Val. loss: 0.037, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.989
# 	Batch 121/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.988
# 	Batch 132/313: 	Train loss: 0.143, 	Train acc.: 0.999, 	Val. loss: 0.038, 	Val. acc.: 0.989
# 	Batch 143/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.990
# 	Batch 154/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.988
# 	Batch 165/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.988
# 	Batch 176/313: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.988
# 	Batch 187/313: 	Train loss: 0.005, 	Train acc.: 0.999, 	Val. loss: 0.098, 	Val. acc.: 0.981
# 	Batch 198/313: 	Train loss: 0.011, 	Train acc.: 0.996, 	Val. loss: 0.061, 	Val. acc.: 0.986
# 	Batch 209/313: 	Train loss: 0.003, 	Train acc.: 0.999, 	Val. loss: 0.045, 	Val. acc.: 0.989
# 	Batch 220/313: 	Train loss: 0.144, 	Train acc.: 0.999, 	Val. loss: 0.040, 	Val. acc.: 0.989
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.990
# 	Batch 242/313: 	Train loss: 0.013, 	Train acc.: 0.996, 	Val. loss: 0.048, 	Val. acc.: 0.987
# 	Batch 253/313: 	Train loss: 0.004, 	Train acc.: 0.999, 	Val. loss: 0.041, 	Val. acc.: 0.987
# 	Batch 264/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.988
# 	Batch 275/313: 	Train loss: 0.008, 	Train acc.: 0.997, 	Val. loss: 0.042, 	Val. acc.: 0.989
# 	Batch 286/313: 	Train loss: 0.145, 	Train acc.: 0.999, 	Val. loss: 0.044, 	Val. acc.: 0.989
# 	Batch 297/313: 	Train loss: 0.014, 	Train acc.: 0.997, 	Val. loss: 0.040, 	Val. acc.: 0.989
# 	Batch 308/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.037, 	Val. acc.: 0.988
# Epoch 4/20: Train loss: 0.018, Train acc.: 0.999, Val. loss: 0.039, Val. acc.: 0.989
# 	Batch 11/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.988
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.989
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.989
# 	Batch 44/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.989
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.989
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.989
# 	Batch 77/313: 	Train loss: 0.143, 	Train acc.: 0.999, 	Val. loss: 0.041, 	Val. acc.: 0.989
# 	Batch 88/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.989
# 	Batch 99/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.990
# 	Batch 110/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.040, 	Val. acc.: 0.989
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.989
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.989
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.989
# 	Batch 154/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.989
# 	Batch 165/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.989
# 	Batch 176/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.044, 	Val. acc.: 0.989
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.989
# 	Batch 198/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.051, 	Val. acc.: 0.989
# 	Batch 209/313: 	Train loss: 0.002, 	Train acc.: 0.999, 	Val. loss: 0.048, 	Val. acc.: 0.988
# 	Batch 220/313: 	Train loss: 0.008, 	Train acc.: 0.999, 	Val. loss: 0.048, 	Val. acc.: 0.989
# 	Batch 231/313: 	Train loss: 0.004, 	Train acc.: 1.000, 	Val. loss: 0.063, 	Val. acc.: 0.987
# 	Batch 242/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.060, 	Val. acc.: 0.987
# 	Batch 253/313: 	Train loss: 0.005, 	Train acc.: 0.997, 	Val. loss: 0.141, 	Val. acc.: 0.974
# 	Batch 264/313: 	Train loss: 0.012, 	Train acc.: 0.994, 	Val. loss: 0.046, 	Val. acc.: 0.990
# 	Batch 275/313: 	Train loss: 0.004, 	Train acc.: 0.999, 	Val. loss: 0.074, 	Val. acc.: 0.983
# 	Batch 286/313: 	Train loss: 0.012, 	Train acc.: 0.994, 	Val. loss: 0.057, 	Val. acc.: 0.987
# 	Batch 297/313: 	Train loss: 0.005, 	Train acc.: 0.997, 	Val. loss: 0.061, 	Val. acc.: 0.986
# 	Batch 308/313: 	Train loss: 0.005, 	Train acc.: 0.999, 	Val. loss: 0.041, 	Val. acc.: 0.989
# Epoch 5/20: Train loss: 0.017, Train acc.: 0.999, Val. loss: 0.040, Val. acc.: 0.989
# 	Batch 11/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.989
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.988
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.987
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.988
# 	Batch 55/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.988
# 	Batch 66/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.988
# 	Batch 77/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.989
# 	Batch 88/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.058, 	Val. acc.: 0.988
# 	Batch 99/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.056, 	Val. acc.: 0.989
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.047, 	Val. acc.: 0.990
# 	Batch 121/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.990
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.052, 	Val. acc.: 0.989
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.989
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.046, 	Val. acc.: 0.990
# 	Batch 165/313: 	Train loss: 0.143, 	Train acc.: 0.999, 	Val. loss: 0.047, 	Val. acc.: 0.990
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.059, 	Val. acc.: 0.989
# 	Batch 187/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.047, 	Val. acc.: 0.989
# 	Batch 198/313: 	Train loss: 0.004, 	Train acc.: 0.999, 	Val. loss: 0.053, 	Val. acc.: 0.990
# 	Batch 209/313: 	Train loss: 0.143, 	Train acc.: 0.999, 	Val. loss: 0.072, 	Val. acc.: 0.987
# 	Batch 220/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.061, 	Val. acc.: 0.989
# 	Batch 231/313: 	Train loss: 0.005, 	Train acc.: 0.996, 	Val. loss: 0.066, 	Val. acc.: 0.988
# 	Batch 242/313: 	Train loss: 0.002, 	Train acc.: 0.999, 	Val. loss: 0.047, 	Val. acc.: 0.989
# 	Batch 253/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.073, 	Val. acc.: 0.987
# 	Batch 264/313: 	Train loss: 0.010, 	Train acc.: 0.996, 	Val. loss: 0.056, 	Val. acc.: 0.988
# 	Batch 275/313: 	Train loss: 0.015, 	Train acc.: 0.999, 	Val. loss: 0.039, 	Val. acc.: 0.990
# 	Batch 286/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.990
# 	Batch 297/313: 	Train loss: 0.017, 	Train acc.: 0.996, 	Val. loss: 0.036, 	Val. acc.: 0.990
# 	Batch 308/313: 	Train loss: 0.003, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.988
# Epoch 6/20: Train loss: 0.018, Train acc.: 0.999, Val. loss: 0.041, Val. acc.: 0.988
# 	Batch 11/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.988
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.990
# 	Batch 33/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.990
# 	Batch 44/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.990
# 	Batch 66/313: 	Train loss: 0.004, 	Train acc.: 0.999, 	Val. loss: 0.054, 	Val. acc.: 0.987
# 	Batch 77/313: 	Train loss: 0.143, 	Train acc.: 0.999, 	Val. loss: 0.041, 	Val. acc.: 0.988
# 	Batch 88/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.049, 	Val. acc.: 0.989
# 	Batch 99/313: 	Train loss: 0.002, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.048, 	Val. acc.: 0.990
# 	Batch 121/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.035, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.036, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.037, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.037, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.039, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.038, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.990
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.992
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.992
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.992
# Epoch 7/20: Train loss: 0.016, Train acc.: 1.000, Val. loss: 0.038, Val. acc.: 0.992
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.992
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.992
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.992
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.992
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.992
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.038, 	Val. acc.: 0.992
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.992
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.992
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.992
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.992
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.039, 	Val. acc.: 0.992
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.992
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.992
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.040, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.992
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.992
# 	Batch 198/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.042, 	Val. acc.: 0.992
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.992
# 	Batch 220/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.992
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.042, 	Val. acc.: 0.992
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.041, 	Val. acc.: 0.992
# 	Batch 253/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.042, 	Val. acc.: 0.992
# 	Batch 264/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.042, 	Val. acc.: 0.992
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.992
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.992
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.992
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.992
# Epoch 8/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.043, Val. acc.: 0.992
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.992
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.043, 	Val. acc.: 0.992
# 	Batch 33/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.043, 	Val. acc.: 0.992
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.992
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.992
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.992
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.045, 	Val. acc.: 0.992
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.044, 	Val. acc.: 0.992
# 	Batch 99/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.045, 	Val. acc.: 0.992
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.045, 	Val. acc.: 0.992
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.077, 	Val. acc.: 0.992
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.077, 	Val. acc.: 0.992
# 	Batch 143/313: 	Train loss: 0.143, 	Train acc.: 0.999, 	Val. loss: 0.078, 	Val. acc.: 0.992
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.078, 	Val. acc.: 0.990
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.079, 	Val. acc.: 0.990
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.078, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.078, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.078, 	Val. acc.: 0.990
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.083, 	Val. acc.: 0.987
# 	Batch 220/313: 	Train loss: 0.001, 	Train acc.: 1.000, 	Val. loss: 0.081, 	Val. acc.: 0.990
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.989
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.989
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.077, 	Val. acc.: 0.988
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.071, 	Val. acc.: 0.989
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.989
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.989
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.989
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.070, 	Val. acc.: 0.989
# Epoch 9/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.070, Val. acc.: 0.989
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.989
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.989
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.069, 	Val. acc.: 0.989
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.068, 	Val. acc.: 0.989
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.084, 	Val. acc.: 0.989
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.084, 	Val. acc.: 0.989
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.084, 	Val. acc.: 0.989
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.099, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.099, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.099, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.099, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.099, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.099, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.099, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.099, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.099, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.099, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.100, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.084, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.084, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.085, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.085, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.085, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.100, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.101, 	Val. acc.: 0.990
# 	Batch 286/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.102, 	Val. acc.: 0.989
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.101, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.085, 	Val. acc.: 0.991
# Epoch 10/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.086, Val. acc.: 0.990
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 44/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 88/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.102, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.086, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.090, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.092, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.092, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.092, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.090, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.089, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.089, 	Val. acc.: 0.991
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.089, 	Val. acc.: 0.991
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.089, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.106, 	Val. acc.: 0.991
# Epoch 11/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.106, Val. acc.: 0.991
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.092, 	Val. acc.: 0.991
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.092, 	Val. acc.: 0.991
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.092, 	Val. acc.: 0.991
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.090, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.105, 	Val. acc.: 0.991
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.105, 	Val. acc.: 0.991
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.105, 	Val. acc.: 0.991
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.106, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.106, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.090, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.090, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.090, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.090, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.090, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.090, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.091, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.106, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# Epoch 12/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.107, Val. acc.: 0.991
# 	Batch 11/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.106, 	Val. acc.: 0.991
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.106, 	Val. acc.: 0.991
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.106, 	Val. acc.: 0.991
# 	Batch 44/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.106, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.106, 	Val. acc.: 0.991
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.106, 	Val. acc.: 0.991
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.106, 	Val. acc.: 0.991
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.092, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 297/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# Epoch 13/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.107, Val. acc.: 0.991
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.107, 	Val. acc.: 0.991
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.108, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# Epoch 14/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.109, Val. acc.: 0.991
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.109, 	Val. acc.: 0.991
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.110, 	Val. acc.: 0.991
# 	Batch 88/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.110, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.110, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.110, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# Epoch 15/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.112, Val. acc.: 0.991
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 33/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 66/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.096, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.096, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.097, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.098, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.098, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.097, 	Val. acc.: 0.991
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.097, 	Val. acc.: 0.991
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.098, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# Epoch 16/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.113, Val. acc.: 0.991
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.284, 	Train acc.: 0.997, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 286/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# Epoch 17/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.113, Val. acc.: 0.991
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 44/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.111, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.112, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# Epoch 18/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.113, Val. acc.: 0.991
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 77/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.113, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.115, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.115, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.115, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.115, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.114, 	Val. acc.: 0.991
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.115, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.115, 	Val. acc.: 0.991
# Epoch 19/20: Train loss: 0.015, Train acc.: 1.000, Val. loss: 0.115, Val. acc.: 0.991
# 	Batch 11/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.116, 	Val. acc.: 0.991
# 	Batch 22/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.115, 	Val. acc.: 0.991
# 	Batch 33/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.116, 	Val. acc.: 0.991
# 	Batch 44/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.117, 	Val. acc.: 0.991
# 	Batch 55/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.118, 	Val. acc.: 0.991
# 	Batch 66/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.117, 	Val. acc.: 0.991
# 	Batch 77/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.117, 	Val. acc.: 0.991
# 	Batch 88/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.116, 	Val. acc.: 0.991
# 	Batch 99/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.116, 	Val. acc.: 0.991
# 	Batch 110/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.116, 	Val. acc.: 0.991
# 	Batch 121/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.115, 	Val. acc.: 0.991
# 	Batch 132/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.115, 	Val. acc.: 0.991
# 	Batch 143/313: 	Train loss: 0.142, 	Train acc.: 0.999, 	Val. loss: 0.115, 	Val. acc.: 0.991
# 	Batch 154/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.115, 	Val. acc.: 0.991
# 	Batch 165/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.116, 	Val. acc.: 0.991
# 	Batch 176/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.117, 	Val. acc.: 0.991
# 	Batch 187/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.117, 	Val. acc.: 0.991
# 	Batch 198/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.117, 	Val. acc.: 0.991
# 	Batch 209/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.118, 	Val. acc.: 0.991
# 	Batch 220/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.117, 	Val. acc.: 0.991
# 	Batch 231/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.117, 	Val. acc.: 0.991
# 	Batch 242/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.118, 	Val. acc.: 0.991
# 	Batch 253/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.118, 	Val. acc.: 0.991
# 	Batch 264/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.118, 	Val. acc.: 0.991
# 	Batch 275/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.118, 	Val. acc.: 0.991
# 	Batch 286/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.118, 	Val. acc.: 0.991
# 	Batch 297/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.118, 	Val. acc.: 0.991
# 	Batch 308/313: 	Train loss: 0.000, 	Train acc.: 1.000, 	Val. loss: 0.118, 	Val. acc.: 0.991
# Epoch 20/20: Train loss: 0.020, Train acc.: 1.000, Val. loss: 0.118, Val. acc.: 0.991

# %% [markdown]
# **(1 point)**
#
# How does the model perform now when trained on the entire dataset, compared to when only trained on the smaller subset of data? Create one plot with the training accuracy and another with the validation accuracy of the two scenarios.

# %%
# YOUR CODE HERE
compare(train_accs_vgg_all, train_accs_vgg_final, 'Training accuracy', 'trained on smaller data', 'trained on entire data')
compare(val_accs_vgg_all, val_accs_vgg_final, 'Validation accuracy', 'trained on smaller data', 'trained on entire data')

# %% [markdown]
# **(2 points)**
#
# What can you conclude from these plots? Did you expect what you observe in the plots, explain!

# %% [markdown]
# **Your answer:**
# Both the model trained on the smaller dataset and the model trained on the entire dataset are with near-perfect training accuracy (1) and very high validation accuracy (approximately 0.99).
#
# 1. The smaller dataset effectively captures the diversity of the larger dataset.
# 2. The results implies the efficacy of transfer learning,  the transfer-learned model can achieve performance close to a model trained on a much larger dataset. It is predictable that the small dataset model performing comparably to the full dataset model when using powerful pre-trained models like VGG16.

# %% [markdown]
# Save the model to a file.

# %%
# YOUR CODE HERE
torch.save({'model_state_dict': model_vgg_final.state_dict(),
            'train_losses': train_losses_vgg_final,
            'train_accs': train_accs_vgg_final,
            'val_losses': val_losses_vgg_final,
            'val_accs': val_accs_vgg_final,
            }, "./model_vgg_final.ckpt")
saved_model = model_vgg_final
checkpoint = torch.load("model_vgg_final.ckpt")
saved_model.load_state_dict(checkpoint['model_state_dict'])

print("Validation accuracies:", checkpoint['val_accs'])
# Out:
# Validation accuracies: [0.986748417721519, 0.9871439873417721, 0.9883306962025317, 0.9893196202531646, 0.989121835443038, 0.9875395569620253, 0.9918908227848101, 0.9920886075949367, 0.989121835443038, 0.9903085443037974, 0.9907041139240507, 0.9912974683544303, 0.991495253164557, 0.9909018987341772, 0.9909018987341772, 0.9909018987341772, 0.9910996835443038, 0.991495253164557, 0.9912974683544303, 0.9909018987341772]

# %% [markdown]
# ## 6. Evaluation on test set (optional)

# %% [markdown]
# Now we'll evaluate your final model, obtained in step 6, on the test set. As mentioned before, the samples in the test set are not labelled, so we can't compute any supervised performance metrics ourselves.
#
# As a bit of fun and to inspire some friendly competition you may instead submit it to Kaggle for evaluation.
#
# Compute the predictions for all samples in the test set according to your best model, and save it in a .csv file with the format expected by the competition.
#
# For the test data we need a slightly different dataset class, due to the lack of labels in the data.
# A more proper way to implement it would be to make a common class which handles both the train and test settings.
# Here, we'll just copy the train dataset class and make some modifications to ignore the labels.
#
# Hints:
# - There is a `sampleSubmission.csv` file included in the zip data. Take a look at it to better understand what is the expected format here.
# - If you don't know how to create and write to files with Python, it's a well-behaved Google search.

# %%
from pathlib import Path
from PIL import Image
from time import time

class TestData(Dataset):
    
    def __init__(self, root: Path, transform):
        root = Path(root)
        if not (root.exists() and root.is_dir()):
            raise ValueError(f"Data root '{root}' is invalid")
            
        self.root = root
        self.transform = transform
        self._samples = self._collect_samples()
            
    def __getitem__(self, index):
        path = self._samples[index]
        num_id = int(path.stem)
        img = Image.open(path)
        if self.transform is not None:
            img = self.transform(img) 
        return img, num_id
    
    def __len__(self):
        return len(self._samples)
    
    def _collect_samples(self):
        test_paths = self._collect_imgs_sub_dir(self.root)
        return sorted(list(test_paths), key=lambda path: int(path.stem))
     
    @staticmethod
    def _collect_imgs_sub_dir(sub_dir: Path):
        if not sub_dir.exists():
            raise ValueError(f"Data root '{self.root}' must contain sub dir '{sub_dir.name}'")
        return sub_dir.glob("*.jpg")
    
    def get_sample_by_id(self, id_):
        id_index = self._samples.index(id_)
        return self[id_index]

# YOUR CODE HERE
import pandas as pd
from tqdm.notebook import tqdm

test_dir = "test"
img_size = 224
batch_size = 64
transform_test = Compose([Resize((img_size, img_size)), ToTensor()])
test_data = TestData(root=test_dir, transform=transform_test)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

num_features = vgg_model.classifier[0].in_features
class SqueezeLayer(nn.Module):
    def forward(self, x):
        return x.squeeze()

optional = nn.Sequential(
    nn.Linear(num_features, 4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096, 4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096, 4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096, 1),
    nn.Sigmoid(),
    SqueezeLayer()
)
vgg_model.classifier = optional

for param in vgg_model.features.parameters():
    param.requires_grad = True

checkpoint_path = "model_vgg_final.ckpt"
checkpoint = torch.load(checkpoint_path, map_location='cpu')
vgg_model.load_state_dict(checkpoint['model_state_dict'])
predictions = []
vgg_model.eval() 

with torch.no_grad():
    for inputs, num_id in tqdm(test_loader, desc='Eval'):
        outputs = vgg_model(inputs)
        predicted = (outputs > 0.5).long()
        predictions.extend(zip(num_id.cpu().numpy(), predicted.cpu().numpy()))

df_predictions = pd.DataFrame(predictions, columns=['id', 'label'])
df_predictions.to_csv('predictions.csv', index=False)
# Out:
# Eval:   0%|          | 0/196 [00:00<?, ?it/s]

# %% [markdown]
# Now that you created your submission file, submit it to Kaggle for evaluation. The [old competition](https://www.kaggle.com/c/dogs-vs-cats) does not allow submissions any more, but you can submit your file to the [new one](https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition) via the "Late submission" button (they use the same data). The Kaggle CLI can be used as well. Kaggle evaluates your submission according to your log-loss score. Which score did you obtain?

# %% [markdown]
# **Your answer:** 0.45591

# %% [markdown]
# What was the username you used for this submission?

# %% [markdown]
# **Your answer:** jingzhang0704
